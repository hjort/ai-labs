# %%
import pandas as pd

filmes = pd.read_csv("dados/movies.csv.bz2")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes = filmes.set_index("filmeId")
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
notas = pd.read_csv("dados/ratings.csv.bz2")
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# # Primeira tentativa de recomendação: heurística de total de votos

# %%
total_de_votos = notas["filmeId"].value_counts()
total_de_votos.head()
# Out:
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: filmeId, dtype: int64

# %%
filmes['total_de_votos'] = total_de_votos
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos  total_de_votos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 2                         Adventure|Children|Fantasy           110.0
# 3                                     Comedy|Romance            52.0
# 4                               Comedy|Drama|Romance             7.0
# 5                                             Comedy            49.0

# %%
filmes.sort_values("total_de_votos", ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos
# filmeId
# 356              Comedy|Drama|Romance|War           329.0
# 318                           Crime|Drama           317.0
# 296           Comedy|Crime|Drama|Thriller           307.0
# 593                 Crime|Horror|Thriller           279.0
# 2571               Action|Sci-Fi|Thriller           278.0
# 260               Action|Adventure|Sci-Fi           251.0
# 480      Action|Adventure|Sci-Fi|Thriller           238.0
# 110                      Action|Drama|War           237.0
# 589                         Action|Sci-Fi           224.0
# 527                             Drama|War           220.0

# %%
notas_medias = notas.groupby("filmeId").mean()["nota"]
notas_medias.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes["nota_media"] = notas_medias
filmes.sort_values("total_de_votos", ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 356              Comedy|Drama|Romance|War           329.0    4.164134
# 318                           Crime|Drama           317.0    4.429022
# 296           Comedy|Crime|Drama|Thriller           307.0    4.197068
# 593                 Crime|Horror|Thriller           279.0    4.161290
# 2571               Action|Sci-Fi|Thriller           278.0    4.192446
# 260               Action|Adventure|Sci-Fi           251.0    4.231076
# 480      Action|Adventure|Sci-Fi|Thriller           238.0    3.750000
# 110                      Action|Drama|War           237.0    4.031646
# 589                         Action|Sci-Fi           224.0    3.970982
# 527                             Drama|War           220.0    4.225000

# %% [markdown]
# # Uma segunda heurística: nota média e filtrando votos

# %%
filmes.sort_values("nota_media", ascending = False).head(10)
# Out:
#                                             titulo                   generos  \
# filmeId
# 88448        Paper Birds (Pájaros de papel) (2010)              Comedy|Drama
# 100556                  Act of Killing, The (2012)               Documentary
# 143031                             Jump In! (2007)      Comedy|Drama|Romance
# 143511                                Human (2015)               Documentary
# 143559                         L.A. Slasher (2015)      Comedy|Crime|Fantasy
# 6201                              Lady Jane (1986)             Drama|Romance
# 102217              Bill Hicks: Revelations (1993)                    Comedy
# 102084                Justice League: Doom (2012)   Action|Animation|Fantasy
# 6192     Open Hearts (Elsker dig for evigt) (2002)                   Romance
# 145994                      Formula of Love (1984)                    Comedy
#
#          total_de_votos  nota_media
# filmeId
# 88448               1.0         5.0
# 100556              1.0         5.0
# 143031              1.0         5.0
# 143511              1.0         5.0
# 143559              1.0         5.0
# 6201                1.0         5.0
# 102217              1.0         5.0
# 102084              1.0         5.0
# 6192                1.0         5.0
# 145994              1.0         5.0

# %%
filmes.query("total_de_votos >= 10").sort_values("nota_media", ascending = False).head(10)
# Out:
#                                         titulo           generos  \
# filmeId
# 1041                     Secrets & Lies (1996)             Drama
# 3451       Guess Who's Coming to Dinner (1967)             Drama
# 1178                     Paths of Glory (1957)         Drama|War
# 1104          Streetcar Named Desire, A (1951)             Drama
# 2360          Celebration, The (Festen) (1998)             Drama
# 1217                                Ran (1985)         Drama|War
# 318           Shawshank Redemption, The (1994)       Crime|Drama
# 951                     His Girl Friday (1940)    Comedy|Romance
# 1927     All Quiet on the Western Front (1930)  Action|Drama|War
# 3468                       Hustler, The (1961)             Drama
#
#          total_de_votos  nota_media
# filmeId
# 1041               11.0    4.590909
# 3451               11.0    4.545455
# 1178               12.0    4.541667
# 1104               20.0    4.475000
# 2360               12.0    4.458333
# 1217               15.0    4.433333
# 318               317.0    4.429022
# 951                14.0    4.392857
# 1927               10.0    4.350000
# 3468               18.0    4.333333

# %%
filmes_com_mais_de_50_votos = filmes.query("total_de_votos >= 50")
filmes_com_mais_de_50_votos.sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 318                       Shawshank Redemption, The (1994)
# 858                                  Godfather, The (1972)
# 2959                                     Fight Club (1999)
# 1276                                 Cool Hand Luke (1967)
# 750      Dr. Strangelove or: How I Learned to Stop Worr...
# 904                                     Rear Window (1954)
# 1221                        Godfather: Part II, The (1974)
# 48516                                 Departed, The (2006)
# 1213                                     Goodfellas (1990)
# 912                                      Casablanca (1942)
#
#                              generos  total_de_votos  nota_media
# filmeId
# 318                      Crime|Drama           317.0    4.429022
# 858                      Crime|Drama           192.0    4.289062
# 2959     Action|Crime|Drama|Thriller           218.0    4.272936
# 1276                           Drama            57.0    4.271930
# 750                       Comedy|War            97.0    4.268041
# 904                 Mystery|Thriller            84.0    4.261905
# 1221                     Crime|Drama           129.0    4.259690
# 48516           Crime|Drama|Thriller           107.0    4.252336
# 1213                     Crime|Drama           126.0    4.250000
# 912                    Drama|Romance           100.0    4.240000

# %%
eu_assisti = [1, 21, 19, 10, 11, 7, 2]
filmes.loc[eu_assisti]
# Out:
#                                         titulo  \
# filmeId
# 1                             Toy Story (1995)
# 21                           Get Shorty (1995)
# 19       Ace Ventura: When Nature Calls (1995)
# 10                            GoldenEye (1995)
# 11              American President, The (1995)
# 7                               Sabrina (1995)
# 2                               Jumanji (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 21                             Comedy|Crime|Thriller            89.0
# 19                                            Comedy            88.0
# 10                         Action|Adventure|Thriller           132.0
# 11                              Comedy|Drama|Romance            70.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
#
#          nota_media
# filmeId
# 1          3.920930
# 21         3.494382
# 19         2.727273
# 10         3.496212
# 11         3.671429
# 7          3.185185
# 2          3.431818

# %%
aventura_infantil_e_fantasia = filmes_com_mais_de_50_votos.query("generos=='Adventure|Children|Fantasy'")
aventura_infantil_e_fantasia.drop(eu_assisti, errors='ignore').sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 4896     Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 41566    Chronicles of Narnia: The Lion, the Witch and ...
#
#                             generos  total_de_votos  nota_media
# filmeId
# 4896     Adventure|Children|Fantasy           107.0    3.761682
# 41566    Adventure|Children|Fantasy            62.0    3.443548

# %%
# Collaborative filtering x Content based filtering

# %% [markdown]
# # Procurar usuários "similares"

# %% [markdown]
# - joão deu nota 4 no filme toy story
# - maria deu nota 5 no filme toy story
# - paulo deu nota 3 no filme toy story
# - joana deu nota 3.5 no filme toy story
#
# x-y ==> distância

# %%
import matplotlib.pyplot as plt
plt.plot(4, 4.5, "go")
plt.plot(5, 5, "yo")
plt.legend(["João", "Maria"])
plt.title("Calcular a distância entre dois usuários")

plt.plot([4, 5], [4.5, 4.5], color="b", linestyle="-")
plt.plot([4, 5], [4.5, 5], color="b", linestyle="-")
plt.plot([5, 5], [4.5, 5], color="b", linestyle="-")

# %%
import numpy as np

joao = np.array([4, 4.5])
maria = np.array([5, 5])

joao - maria
# Out:
# array([-1. , -0.5])

# %%
from math import sqrt

def pitagoras(a,b):
  (delta_x, delta_y) = a - b
  return sqrt(delta_x * delta_x + delta_y * delta_y)

pitagoras(joao, maria)
# Out:
# 1.118033988749895

# %%
def pitagoras(a,b):
  return np.linalg.norm(a - b)

pitagoras(joao, maria)
# Out:
# 1.118033988749895

# %%
import matplotlib.pyplot as plt
plt.plot(4, 4.5, "go")
plt.plot(5, 5, "yo")
plt.plot(3.5, 4.5, "bo")
plt.legend(["João", "Maria", "Joaquina"])
plt.title("Calcular a distância entre usuários")
# Out:
# Text(0.5, 1.0, 'Calcular a distância entre usuários')

# %%
joaquina = np.array([3.5, 4.5])

print(pitagoras(joao, maria))
print(pitagoras(joao, joaquina))
# Out:
# 1.118033988749895
# 0.5

# %% [markdown]
# # Distância entre usuários do dataset

# %%
def distancia_de_vetores(a,b):
  return np.linalg.norm(a - b)

# %%
def notas_do_usuario(usuario):
  notas_do_usuario = notas.query("usuarioId==%d" % usuario)
  notas_do_usuario = notas_do_usuario[["filmeId", "nota"]].set_index("filmeId")
  return notas_do_usuario

# %%
usuario1 = notas_do_usuario(1)
usuario4 = notas_do_usuario(4)

# %%
usuario1.head()
# Out:
#          nota
# filmeId
# 1         4.0
# 3         4.0
# 6         4.0
# 47        5.0
# 50        5.0

# %%
usuario4.head()
# Out:
#          nota
# filmeId
# 21        3.0
# 32        2.0
# 45        3.0
# 47        2.0
# 52        3.0

# %%
diferencas = usuario1.join(usuario4, lsuffix="_esquerda", rsuffix="_direita").dropna()
distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
# Out:
# 11.135528725660043

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
distancia_de_usuarios(1,4)
# Out:
# [1, 4, 11.135528725660043]

# %%
quantidade_de_usuarios = len(notas['usuarioId'].unique())
print("Temos %d usuarios" % quantidade_de_usuarios)
# Out:
# Temos 610 usuarios

# %%
def distancia_de_todos(voce_id):
  distancias = []
  for usuario_id in notas['usuarioId'].unique():
    informacoes = distancia_de_usuarios(voce_id, usuario_id)
    distancias.append(informacoes)
  return distancias

distancia_de_todos(1)[:5]
# Out:
# [[1, 1, 0.0],
#  [1, 2, 1.4142135623730951],
#  [1, 3, 8.200609733428363],
#  [1, 4, 11.135528725660043],
#  [1, 5, 3.7416573867739413]]

# %%
def distancia_de_todos(voce_id):
  todos_os_usuarios = notas['usuarioId'].unique()
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

distancia_de_todos(1).head()
# Out:
#    voce  outra_pessoa  distancia
# 0     1             1   0.000000
# 1     1             2   1.414214
# 2     1             3   8.200610
# 3     1             4  11.135529
# 4     1             5   3.741657

# %%
notas_do_usuario(1).join(notas_do_usuario(5), lsuffix="_1", rsuffix="5").dropna()
# Out:
#          nota_1  nota5
# filmeId
# 1           4.0    4.0
# 50          5.0    4.0
# 110         4.0    4.0
# 296         3.0    5.0
# 316         3.0    2.0
# 349         4.0    3.0
# 367         4.0    4.0
# 457         5.0    4.0
# 527         5.0    5.0
# 590         4.0    5.0
# 592         4.0    3.0
# 596         5.0    5.0
# 608         5.0    3.0

# %%
notas_do_usuario(1).join(notas_do_usuario(2), lsuffix="_1", rsuffix="2").dropna()
# Out:
#          nota_1  nota2
# filmeId
# 333         5.0    4.0
# 3578        5.0    4.0

# %%
notas_do_usuario(1).join(notas_do_usuario(3), lsuffix="_1", rsuffix="3").dropna()
# Out:
#          nota_1  nota3
# filmeId
# 527         5.0    0.5
# 1275        5.0    3.5
# 1587        5.0    4.5
# 2018        5.0    0.5
# 2090        5.0    0.5
# 2105        4.0    2.0
# 3703        5.0    5.0

# %% [markdown]
# # Usuários sem filmes em comum são colocados bem distante um do outro

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  
  if(len(diferencas) < minimo):
    return [usuario_id1, usuario_id2, 100000]
  
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
distancia_de_todos(1).head()
# Out:
#    voce  outra_pessoa      distancia
# 0     1             1       0.000000
# 1     1             2  100000.000000
# 2     1             3       8.200610
# 3     1             4      11.135529
# 4     1             5       3.741657

# %%
def mais_proximos_de(voce_id):
  distancias = distancia_de_todos(voce_id)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
mais_proximos_de(1).head()
# Out:
#               voce  distancia
# outra_pessoa
# 77               1   0.000000
# 511              1   0.500000
# 366              1   0.707107
# 523              1   1.000000
# 49               1   1.000000

# %% [markdown]
# # Parâmetros para teste

# %%
def mais_proximos_de(voce_id, n = None):
  distancias = distancia_de_todos(voce_id, n = n)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
def distancia_de_todos(voce_id, n = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if n:
    todos_os_usuarios = todos_os_usuarios[:n]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
mais_proximos_de(1, n = 50)
# Out:
#               voce      distancia
# outra_pessoa
# 49               1       1.000000
# 9                1       1.000000
# 13               1       1.414214
# 25               1       1.414214
# 30               1       1.802776
# 35               1       2.236068
# 26               1       2.236068
# 46               1       3.316625
# 8                1       3.741657
# 44               1       3.741657
# 5                1       3.741657
# 37               1       4.000000
# 48               1       4.123106
# 11               1       4.242641
# 24               1       4.415880
# 29               1       4.555217
# 31               1       4.582576
# 17               1       4.609772
# 43               1       4.795832
# 14               1       5.000000
# 32               1       5.196152
# 22               1       5.244044
# 23               1       5.408327
# 38               1       5.567764
# 15               1       5.852350
# 33               1       5.916080
# 47               1       6.244998
# 34               1       6.363961
# 20               1       6.480741
# 36               1       6.519202
# 40               1       6.855655
# 7                1       7.106335
# 16               1       7.228416
# 50               1       7.331439
# 10               1       7.858117
# 3                1       8.200610
# 18               1       8.426150
# 6                1       8.602325
# 21               1       9.096703
# 27               1       9.219544
# 41               1      10.198039
# 45               1      10.653638
# 39               1      11.090537
# 4                1      11.135529
# 42               1      12.000000
# 28               1      14.882876
# 19               1      17.606817
# 2                1  100000.000000
# 12               1  100000.000000

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  
  if(len(diferencas) < minimo):
    return None
  
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
def distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if numero_de_usuarios_a_analisar:
    todos_os_usuarios = todos_os_usuarios[:numero_de_usuarios_a_analisar]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = list(filter(None, distancias))
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
def mais_proximos_de(voce_id, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
mais_proximos_de(1, numero_de_usuarios_a_analisar = 50)
# Out:
#               voce  distancia
# outra_pessoa
# 49               1   1.000000
# 9                1   1.000000
# 25               1   1.414214
# 13               1   1.414214
# 30               1   1.802776
# 35               1   2.236068
# 26               1   2.236068
# 46               1   3.316625
# 8                1   3.741657
# 5                1   3.741657
# 44               1   3.741657
# 37               1   4.000000
# 48               1   4.123106
# 11               1   4.242641
# 24               1   4.415880
# 29               1   4.555217
# 31               1   4.582576
# 17               1   4.609772
# 43               1   4.795832
# 14               1   5.000000
# 32               1   5.196152
# 22               1   5.244044
# 23               1   5.408327
# 38               1   5.567764
# 15               1   5.852350
# 33               1   5.916080
# 47               1   6.244998
# 34               1   6.363961
# 20               1   6.480741
# 36               1   6.519202
# 40               1   6.855655
# 7                1   7.106335
# 16               1   7.228416
# 50               1   7.331439
# 10               1   7.858117
# 3                1   8.200610
# 18               1   8.426150
# 6                1   8.602325
# 21               1   9.096703
# 27               1   9.219544
# 41               1  10.198039
# 45               1  10.653638
# 39               1  11.090537
# 4                1  11.135529
# 42               1  12.000000
# 28               1  14.882876
# 19               1  17.606817

# %%
def sugere_para(voce, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  similar = similares.iloc[0].name
  notas_do_similar = notas_do_usuario(similar)
  notas_do_similar = notas_do_similar.drop(filmes_que_voce_ja_viu, errors='ignore')
  recomendacoes = notas_do_similar.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar=50).head()
# Out:
#          nota                            titulo  \
# filmeId
# 1200      4.5                     Aliens (1986)
# 4022      4.5                  Cast Away (2000)
# 47099     4.5  Pursuit of Happyness, The (2006)
# 79132     4.5                  Inception (2010)
# 109487    4.5               Interstellar (2014)
#
#                                                  generos  total_de_votos  \
# filmeId
# 1200                      Action|Adventure|Horror|Sci-Fi           126.0
# 4022                                               Drama           100.0
# 47099                                              Drama            46.0
# 79132    Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX           143.0
# 109487                                       Sci-Fi|IMAX            73.0
#
#          nota_media
# filmeId
# 1200       3.964286
# 4022       3.700000
# 47099      3.793478
# 79132      4.066434
# 109487     3.993151

# %%
sugere_para(1).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 8636      5.0                                Spider-Man 2 (2004)
# 58559     5.0                            Dark Knight, The (2008)
# 33794     5.0                               Batman Begins (2005)
# 4993      5.0  Lord of the Rings: The Fellowship of the Ring,...
# 5349      5.0                                  Spider-Man (2002)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 8636         Action|Adventure|Sci-Fi|IMAX            79.0    3.803797
# 58559             Action|Crime|Drama|IMAX           149.0    4.238255
# 33794                   Action|Crime|IMAX           116.0    3.862069
# 4993                    Adventure|Fantasy           198.0    4.106061
# 5349     Action|Adventure|Sci-Fi|Thriller           122.0    3.540984

# %% [markdown]
# # Sugerindo baseado em vários usuários

# %%
def mais_proximos_de(voce_id, n_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias.head(n_mais_proximos)

# %%
mais_proximos_de(1, n_mais_proximos = 2, numero_de_usuarios_a_analisar=300)
# Out:
#               voce  distancia
# outra_pessoa
# 77               1        0.0
# 258              1        1.0

# %%
def sugere_para(voce, n_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, n_mais_proximos = n_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  recomendacoes = recomendacoes.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar = 50).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 187593    5.0                                  Deadpool 2 (2018)
# 68157     5.0                        Inglourious Basterds (2009)
# 475       5.0                   In the Name of the Father (1993)
# 33794     5.0                               Batman Begins (2005)
# 7153      5.0  Lord of the Rings: The Return of the King, The...
#
#                                 generos  total_de_votos  nota_media
# filmeId
# 187593             Action|Comedy|Sci-Fi            12.0    3.875000
# 68157                  Action|Drama|War            88.0    4.136364
# 475                               Drama            25.0    4.300000
# 33794                 Action|Crime|IMAX           116.0    3.862069
# 7153     Action|Adventure|Drama|Fantasy           185.0    4.118919

# %%
sugere_para(1, numero_de_usuarios_a_analisar = 300).head()
# Out:
#          nota                                          titulo  \
# filmeId
# 187593    5.0                               Deadpool 2 (2018)
# 802       5.0                               Phenomenon (1996)
# 534       5.0                              Shadowlands (1993)
# 1172      5.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# 515       5.0                  Remains of the Day, The (1993)
#
#                       generos  total_de_votos  nota_media
# filmeId
# 187593   Action|Comedy|Sci-Fi            12.0    3.875000
# 802             Drama|Romance            46.0    3.336957
# 534             Drama|Romance            14.0    3.607143
# 1172                    Drama            34.0    4.161765
# 515             Drama|Romance            24.0    3.604167

# %%
sugere_para(1).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 1704      5.0                           Good Will Hunting (1997)
# 57504     5.0  Girl Who Leapt Through Time, The (Toki o kaker...
# 38304     5.0                No Direction Home: Bob Dylan (2005)
# 48394     5.0   Pan's Labyrinth (Laberinto del fauno, El) (2006)
# 2300      5.0                              Producers, The (1968)
#
#                                        generos  total_de_votos  nota_media
# filmeId
# 1704                             Drama|Romance           141.0    4.078014
# 57504    Animation|Comedy|Drama|Romance|Sci-Fi            10.0    4.100000
# 38304                              Documentary             4.0    4.625000
# 48394                   Drama|Fantasy|Thriller            81.0    3.814815
# 2300                                    Comedy            33.0    3.969697

# %%
def knn(voce_id, k_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias.head(k_mais_proximos)

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = knn(voce, k_mais_proximos = k_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  recomendacoes = recomendacoes.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %% [markdown]
# # Testar um usuário novo

# %%
filmes.loc[[122904, 1246, 2529, 2329, 2324, 1, 7, 2, 1196, 260]]
# Out:
#                                                     titulo  \
# filmeId
# 122904                                     Deadpool (2016)
# 1246                             Dead Poets Society (1989)
# 2529                             Planet of the Apes (1968)
# 2329                             American History X (1998)
# 2324            Life Is Beautiful (La Vita è bella) (1997)
# 1                                         Toy Story (1995)
# 7                                           Sabrina (1995)
# 2                                           Jumanji (1995)
# 1196     Star Wars: Episode V - The Empire Strikes Back...
# 260              Star Wars: Episode IV - A New Hope (1977)
#
#                                              generos  total_de_votos  \
# filmeId
# 122904                Action|Adventure|Comedy|Sci-Fi            54.0
# 1246                                           Drama            86.0
# 2529                             Action|Drama|Sci-Fi            56.0
# 2329                                     Crime|Drama           129.0
# 2324                        Comedy|Drama|Romance|War            88.0
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
# 1196                         Action|Adventure|Sci-Fi           211.0
# 260                          Action|Adventure|Sci-Fi           251.0
#
#          nota_media
# filmeId
# 122904     3.833333
# 1246       3.959302
# 2529       3.803571
# 2329       4.217054
# 2324       4.147727
# 1          3.920930
# 7          3.185185
# 2          3.431818
# 1196       4.215640
# 260        4.231076

# %%
def novo_usuario(dados):
  novo_usuario = notas['usuarioId'].max() + 1
  notas_do_usuario_novo = pd.DataFrame(dados, columns=["filmeId", "nota"])
  notas_do_usuario_novo['usuarioId'] = novo_usuario
  return pd.concat([notas, notas_do_usuario_novo])

# %%
notas = novo_usuario([[122904,2],[1246,5],[2529,2],[2329,5],[2324,5],[1,2],[7,0.5],[2,2],[1196,1],[260,1]])
notas.tail()
# Out:
# /dados/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#    filmeId  momento  nota  usuarioId
# 5        1      NaN   2.0        611
# 6        7      NaN   0.5        611
# 7        2      NaN   2.0        611
# 8     1196      NaN   1.0        611
# 9      260      NaN   1.0        611

# %%
# recuperar identificação do usuário recém-inserido
usuario_inserido = notas['usuarioId'].max()
usuario_inserido
# Out:
# 611

# %%
sugere_para(usuario_inserido).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 171495    5.0                                             Cosmos
# 81847     5.0                                     Tangled (2010)
# 1873      5.0                             Misérables, Les (1998)
# 8014      5.0  Spring, Summer, Fall, Winter... and Spring (Bo...
# 103141    5.0                         Monsters University (2013)
#
#                                                    generos  total_de_votos  \
# filmeId
# 171495                                  (no genres listed)             2.0
# 81847    Animation|Children|Comedy|Fantasy|Musical|Roma...            24.0
# 1873                               Crime|Drama|Romance|War            10.0
# 8014                                                 Drama            10.0
# 103141                          Adventure|Animation|Comedy            16.0
#
#          nota_media
# filmeId
# 171495     4.500000
# 81847      3.916667
# 1873       3.750000
# 8014       4.250000
# 103141     3.875000

# %% [markdown]
# # Utilizar somente as notas de filmes com mais de 50 votos

# %%
notas = notas.set_index("filmeId").loc[filmes_com_mais_de_50_votos.index]
notas.head()
# Out:
#               momento  nota  usuarioId
# filmeId
# 1        9.649827e+08   4.0          1
# 1        8.474350e+08   4.0          5
# 1        1.106636e+09   4.5          7
# 1        1.510578e+09   2.5         15
# 1        1.305696e+09   4.5         17

# %%
notas = notas.reset_index()
notas.head()
# Out:
#    filmeId       momento  nota  usuarioId
# 0        1  9.649827e+08   4.0          1
# 1        1  8.474350e+08   4.0          5
# 2        1  1.106636e+09   4.5          7
# 3        1  1.510578e+09   2.5         15
# 4        1  1.305696e+09   4.5         17

# %%
sugere_para(8621).head()
# Out:
#          nota                                        titulo  \
# filmeId
# 3334      5.0                              Key Largo (1948)
# 1243      5.0  Rosencrantz and Guildenstern Are Dead (1990)
# 1284      5.0                         Big Sleep, The (1946)
# 2926      5.0                              Hairspray (1988)
# 1276      5.0                         Cool Hand Luke (1967)
#
#                                 generos  total_de_votos  nota_media
# filmeId
# 3334     Crime|Drama|Film-Noir|Thriller            89.0    3.870787
# 1243                       Comedy|Drama           130.0    3.911538
# 1284            Crime|Film-Noir|Mystery           176.0    4.116477
# 2926                       Comedy|Drama           138.0    3.206522
# 1276                              Drama           403.0    4.127792

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = knn(voce, k_mais_proximos = k_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  aparicoes = notas_dos_similares.groupby("filmeId").count()[['nota']]
  
  filtro_minimo = k_mais_proximos / 2
  recomendacoes = recomendacoes.join(aparicoes, lsuffix="_media_dos_usuarios", rsuffix="_aparicoes_nos_usuarios")
  recomendacoes = recomendacoes.query("nota_aparicoes_nos_usuarios >= %.2f" % filtro_minimo)  
  recomendacoes = recomendacoes.sort_values("nota_media_dos_usuarios", ascending=False)
  recomendacoes = recomendacoes.drop(filmes_que_voce_ja_viu,errors='ignore')
  return recomendacoes.join(filmes)

# %%
def knn(voce_id, k_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id, errors='ignore')
  return distancias.head(k_mais_proximos)

# %%
sugere_para(1, numero_de_usuarios_a_analisar=500)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 2300                    4.750000                            6
# 3683                    4.750000                            6
# 2858                    4.750000                            8
# 1208                    4.714286                            7
# 5618                    4.714286                            7
# 1201                    4.687500                            8
# 858                     4.666667                            6
# 1221                    4.666667                            6
# 50                      4.666667                            9
# 260                     4.625000                            8
# 6711                    4.571429                            7
# 7153                    4.571429                            7
# 1213                    4.562500                            8
# 1197                    4.555556                            9
# 4993                    4.555556                            9
# 593                     4.550000                           10
# 296                     4.550000                           10
# 56782                   4.500000                            5
# 2997                    4.500000                            8
# 2959                    4.500000                            8
# 37733                   4.500000                            5
# 5952                    4.500000                            7
# 4641                    4.500000                            6
# 318                     4.500000                            9
# 994                     4.500000                            5
# 1259                    4.444444                            9
# 1222                    4.444444                            9
# 1089                    4.437500                            8
# 1214                    4.437500                            8
# 4226                    4.437500                            8
# ...                          ...                          ...
# 1831                    2.625000                            8
# 1405                    2.600000                            5
# 3752                    2.600000                            5
# 3438                    2.600000                            5
# 587                     2.600000                            5
# 3753                    2.583333                            6
# 273                     2.583333                            6
# 3247                    2.583333                            6
# 585                     2.571429                            7
# 2143                    2.500000                            7
# 350                     2.500000                            5
# 1499                    2.416667                            6
# 1597                    2.400000                            5
# 724                     2.400000                            5
# 44                      2.400000                            5
# 186                     2.400000                            5
# 333                     2.400000                            5
# 2411                    2.400000                            5
# 435                     2.333333                            6
# 880                     2.300000                            5
# 185                     2.250000                            6
# 282                     2.250000                            6
# 2088                    2.200000                            5
# 3257                    2.200000                            5
# 1644                    2.166667                            6
# 2881                    2.100000                            5
# 355                     2.083333                            6
# 1037                    2.000000                            5
# 1562                    1.785714                            7
# 546                     1.600000                            5
#
#                                                     titulo  \
# filmeId
# 2300                                 Producers, The (1968)
# 3683                                   Blood Simple (1984)
# 2858                                American Beauty (1999)
# 1208                                 Apocalypse Now (1979)
# 5618     Spirited Away (Sen to Chihiro no kamikakushi) ...
# 1201     Good, the Bad and the Ugly, The (Buono, il bru...
# 858                                  Godfather, The (1972)
# 1221                        Godfather: Part II, The (1974)
# 50                              Usual Suspects, The (1995)
# 260              Star Wars: Episode IV - A New Hope (1977)
# 6711                            Lost in Translation (2003)
# 7153     Lord of the Rings: The Return of the King, The...
# 1213                                     Goodfellas (1990)
# 1197                            Princess Bride, The (1987)
# 4993     Lord of the Rings: The Fellowship of the Ring,...
# 593                       Silence of the Lambs, The (1991)
# 296                                    Pulp Fiction (1994)
# 56782                           There Will Be Blood (2007)
# 2997                           Being John Malkovich (1999)
# 2959                                     Fight Club (1999)
# 37733                        History of Violence, A (2005)
# 5952         Lord of the Rings: The Two Towers, The (2002)
# 4641                                    Ghost World (2001)
# 318                       Shawshank Redemption, The (1994)
# 994                                       Big Night (1996)
# 1259                                    Stand by Me (1986)
# 1222                              Full Metal Jacket (1987)
# 1089                                 Reservoir Dogs (1992)
# 1214                                          Alien (1979)
# 4226                                        Memento (2000)
# ...                                                    ...
# 1831                                  Lost in Space (1998)
# 1405                Beavis and Butt-Head Do America (1996)
# 3752                             Me, Myself & Irene (2000)
# 3438                   Teenage Mutant Ninja Turtles (1990)
# 587                                           Ghost (1990)
# 3753                                   Patriot, The (2000)
# 273      Mary Shelley's Frankenstein (Frankenstein) (1994)
# 3247                                     Sister Act (1992)
# 585                          Brady Bunch Movie, The (1995)
# 2143                                         Legend (1985)
# 350                                     Client, The (1994)
# 1499                                       Anaconda (1997)
# 1597                              Conspiracy Theory (1997)
# 724                                      Craft, The (1996)
# 44                                    Mortal Kombat (1995)
# 186                                     Nine Months (1995)
# 333                                       Tommy Boy (1995)
# 2411                                       Rocky IV (1985)
# 435                                       Coneheads (1993)
# 880                       Island of Dr. Moreau, The (1996)
# 185                                        Net, The (1995)
# 282                                            Nell (1994)
# 2088                                         Popeye (1980)
# 3257                                 Bodyguard, The (1992)
# 1644                I Know What You Did Last Summer (1997)
# 2881                                Double Jeopardy (1999)
# 355                                Flintstones, The (1994)
# 1037                             Lawnmower Man, The (1992)
# 1562                                 Batman & Robin (1997)
# 546                               Super Mario Bros. (1993)
#
#                                                  generos  total_de_votos  \
# filmeId
# 2300                                              Comedy           231.0
# 3683                               Crime|Drama|Film-Noir           190.0
# 2858                                       Drama|Romance          1795.0
# 1208                                    Action|Drama|War           878.0
# 5618                         Adventure|Animation|Fantasy           694.0
# 1201                            Action|Adventure|Western           574.0
# 858                                          Crime|Drama          1836.0
# 1221                                         Crime|Drama          1212.0
# 50                                Crime|Mystery|Thriller          1897.0
# 260                              Action|Adventure|Sci-Fi          2478.0
# 6711                                Comedy|Drama|Romance           650.0
# 7153                      Action|Adventure|Drama|Fantasy          1699.0
# 1213                                         Crime|Drama          1071.0
# 1197             Action|Adventure|Comedy|Fantasy|Romance          1276.0
# 4993                                   Adventure|Fantasy          1834.0
# 593                                Crime|Horror|Thriller          2650.0
# 296                          Comedy|Crime|Drama|Thriller          2780.0
# 56782                                      Drama|Western           305.0
# 2997                                Comedy|Drama|Fantasy          1030.0
# 2959                         Action|Crime|Drama|Thriller          1925.0
# 37733                        Action|Crime|Drama|Thriller           185.0
# 5952                                   Adventure|Fantasy          1691.0
# 4641                                        Comedy|Drama           236.0
# 318                                          Crime|Drama          2926.0
# 994                                         Comedy|Drama           168.0
# 1259                                     Adventure|Drama           770.0
# 1222                                           Drama|War           853.0
# 1089                              Crime|Mystery|Thriller          1077.0
# 1214                                       Horror|Sci-Fi          1197.0
# 4226                                    Mystery|Thriller          1328.0
# ...                                                  ...             ...
# 1831                             Action|Adventure|Sci-Fi           292.0
# 1405                    Adventure|Animation|Comedy|Crime           319.0
# 3752                                    Adventure|Comedy           348.0
# 3438               Action|Children|Comedy|Fantasy|Sci-Fi           176.0
# 587                Comedy|Drama|Fantasy|Romance|Thriller           995.0
# 3753                                    Action|Drama|War           501.0
# 273                                  Drama|Horror|Sci-Fi           295.0
# 3247                                        Comedy|Crime           255.0
# 585                                               Comedy           350.0
# 2143                           Adventure|Fantasy|Romance           113.0
# 350                               Drama|Mystery|Thriller           530.0
# 1499                           Action|Adventure|Thriller           225.0
# 1597                      Drama|Mystery|Romance|Thriller           371.0
# 724                        Drama|Fantasy|Horror|Thriller           314.0
# 44                              Action|Adventure|Fantasy           427.0
# 186                                       Comedy|Romance           411.0
# 333                                               Comedy           426.0
# 2411                                        Action|Drama           207.0
# 435                                        Comedy|Sci-Fi           491.0
# 880                                      Sci-Fi|Thriller           186.0
# 185                                Action|Crime|Thriller           809.0
# 282                                                Drama           363.0
# 2088                            Adventure|Comedy|Musical           119.0
# 3257                              Drama|Romance|Thriller           241.0
# 1644                             Horror|Mystery|Thriller           299.0
# 2881                         Action|Crime|Drama|Thriller           291.0
# 355                              Children|Comedy|Fantasy           351.0
# 1037                       Action|Horror|Sci-Fi|Thriller           249.0
# 1562                   Action|Adventure|Fantasy|Thriller           359.0
# 546      Action|Adventure|Children|Comedy|Fantasy|Sci-Fi           220.0
#
#          nota_media
# filmeId
# 2300       3.893939
# 3683       4.036842
# 2858       4.148468
# 1208       4.088838
# 5618       4.224063
# 1201       4.143728
# 858        4.307462
# 1221       4.261139
# 50         4.303374
# 260        4.124294
# 6711       3.854615
# 7153       4.155386
# 1213       4.147526
# 1197       4.094044
# 4993       4.143675
# 593        4.130943
# 296        4.166906
# 56782      4.019672
# 2997       3.940777
# 2959       4.221299
# 37733      3.597297
# 5952       4.129805
# 4641       3.809322
# 318        4.409433
# 994        3.991071
# 1259       3.976623
# 1222       4.081477
# 1089       4.113278
# 1214       4.088137
# 4226       4.172440
# ...             ...
# 1831       2.645548
# 1405       2.935737
# 3752       3.010057
# 3438       2.846591
# 587        3.391457
# 3753       3.407186
# 273        3.157627
# 3247       2.954902
# 585        2.712857
# 2143       3.115044
# 350        3.500943
# 1499       2.111111
# 1597       3.340970
# 724        3.079618
# 44         2.696721
# 186        2.863747
# 333        3.441315
# 2411       3.108696
# 435        2.584521
# 880        2.537634
# 185        3.087145
# 282        3.477961
# 2088       2.500000
# 3257       2.856846
# 1644       2.533445
# 2881       3.316151
# 355        2.460114
# 1037       2.736948
# 1562       2.183844
# 546        2.086364
#
# [697 rows x 6 columns]

# %%
sugere_para(8621).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 1136                    4.750000                            6
# 4878                    4.600000                            5
# 293                     4.500000                            6
# 1080                    4.500000                            5
# 296                     4.444444                            9
# 608                     4.375000                            8
# 1259                    4.357143                            7
# 3147                    4.333333                            6
# 2858                    4.333333                            9
# 4262                    4.300000                            5
#
#                                                     titulo  \
# filmeId
# 1136                Monty Python and the Holy Grail (1975)
# 4878                                   Donnie Darko (2001)
# 293      Léon: The Professional (a.k.a. The Professiona...
# 1080                   Monty Python's Life of Brian (1979)
# 296                                    Pulp Fiction (1994)
# 608                                           Fargo (1996)
# 1259                                    Stand by Me (1986)
# 3147                                Green Mile, The (1999)
# 2858                                American Beauty (1999)
# 4262                                       Scarface (1983)
#
#                                generos  total_de_votos  nota_media
# filmeId
# 1136          Adventure|Comedy|Fantasy          1230.0    4.113821
# 4878     Drama|Mystery|Sci-Fi|Thriller           860.0    3.977907
# 293        Action|Crime|Drama|Thriller          1117.0    4.089973
# 1080                            Comedy           800.0    3.946250
# 296        Comedy|Crime|Drama|Thriller          2780.0    4.166906
# 608        Comedy|Crime|Drama|Thriller          1653.0    4.111313
# 1259                   Adventure|Drama           770.0    3.976623
# 3147                       Crime|Drama          1006.0    4.013419
# 2858                     Drama|Romance          1795.0    4.148468
# 4262                Action|Crime|Drama           464.0    3.897629

# %%
sugere_para(8621, k_mais_proximos=20).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 318                     4.400000                           15
# 4973                    4.300000                           10
# 50                      4.208333                           12
# 1213                    4.181818                           11
# 48516                   4.150000                           10
# 527                     4.133333                           15
# 47                      4.066667                           15
# 778                     4.045455                           11
# 1961                    4.041667                           12
# 1193                    4.000000                           13
#
#                                                     titulo  \
# filmeId
# 318                       Shawshank Redemption, The (1994)
# 4973     Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 50                              Usual Suspects, The (1995)
# 1213                                     Goodfellas (1990)
# 48516                                 Departed, The (2006)
# 527                                Schindler's List (1993)
# 47                             Seven (a.k.a. Se7en) (1995)
# 778                                   Trainspotting (1996)
# 1961                                       Rain Man (1988)
# 1193                One Flew Over the Cuckoo's Nest (1975)
#
#                         generos  total_de_votos  nota_media
# filmeId
# 318                 Crime|Drama          2926.0    4.409433
# 4973             Comedy|Romance          1128.0    4.098404
# 50       Crime|Mystery|Thriller          1897.0    4.303374
# 1213                Crime|Drama          1071.0    4.147526
# 48516      Crime|Drama|Thriller           740.0    4.139865
# 527                   Drama|War          2156.0    4.232607
# 47             Mystery|Thriller          1707.0    4.044523
# 778          Comedy|Crime|Drama           999.0    4.021522
# 1961                      Drama           980.0    3.901020
# 1193                      Drama          1262.0    4.200475
