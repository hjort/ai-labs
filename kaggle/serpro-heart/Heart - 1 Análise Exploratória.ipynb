# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 3)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('heart-train.csv', index_col='Paciente')

# substituir valor '?' por nulo
data.replace('?', np.nan, inplace=True)

# converter tipos para numérico
for col in ['PAR', 'CS', 'FCM', 'DST']:
    data[col] = data[col].astype(float)
for col in ['ASJ', 'ECG', 'AIE', 'IST', 'NVP', 'Talassemia']:
    data[col] = data[col].astype(float)
    
# mostrar alguns exemplos de registros
data.head()
# Out:
#          Hospital  Idade Sexo  TDP    PAR     CS  ASJ  ECG    FCM  AIE  DST  \
# Paciente
# 262             C     60    F    1  150.0  240.0  0.0  0.0  171.0  0.0  0.9
# 520             H     54    M    4  125.0  224.0  0.0  0.0  122.0  0.0  2.0
# 264             C     61    M    4  138.0  166.0  0.0  2.0  125.0  1.0  3.6
# 674             S     60    M    3  115.0    0.0  NaN  0.0  143.0  0.0  2.4
# 102             C     57    F    4  128.0  303.0  0.0  2.0  159.0  0.0  0.0
#
#           IST  NVP  Talassemia Diagnóstico
# Paciente
# 262       1.0  0.0         3.0           A
# 520       2.0  NaN         NaN           P
# 264       2.0  1.0         3.0           P
# 674       1.0  NaN         NaN           P
# 102       1.0  1.0         3.0           A

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (613, 15)

# %% [markdown]
# ## Análise dos dados

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 613 entries, 262 to 173
# Data columns (total 15 columns):
# Hospital       613 non-null object
# Idade          613 non-null int64
# Sexo           613 non-null object
# TDP            613 non-null int64
# PAR            571 non-null float64
# CS             593 non-null float64
# ASJ            553 non-null float64
# ECG            611 non-null float64
# FCM            574 non-null float64
# AIE            574 non-null float64
# DST            569 non-null float64
# IST            398 non-null float64
# NVP            207 non-null float64
# Talassemia     293 non-null float64
# Diagnóstico    613 non-null object
# dtypes: float64(10), int64(2), object(3)
# memory usage: 76.6+ KB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# PAR            42
# CS             20
# ASJ            60
# ECG             2
# FCM            39
# AIE            39
# DST            44
# IST           215
# NVP           406
# Talassemia    320
# dtype: int64

# %%
data.isna().sum()
# Out:
# Hospital         0
# Idade            0
# Sexo             0
# TDP              0
# PAR             42
# CS              20
# ASJ             60
# ECG              2
# FCM             39
# AIE             39
# DST             44
# IST            215
# NVP            406
# Talassemia     320
# Diagnóstico      0
# dtype: int64

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#             count     mean      std   min     25%    50%    75%    max
# Idade       613.0   53.723    9.473  28.0   47.00   54.0   60.0   77.0
# TDP         613.0    3.269    0.903   1.0    3.00    4.0    4.0    4.0
# PAR         571.0  132.361   18.024  80.0  120.00  130.0  142.0  200.0
# CS          593.0  199.779  112.728   0.0  173.00  223.0  267.0  603.0
# ASJ         553.0    0.177    0.382   0.0    0.00    0.0    0.0    1.0
# ECG         611.0    0.609    0.809   0.0    0.00    0.0    1.0    2.0
# FCM         574.0  136.455   26.348  60.0  119.25  138.0  157.0  202.0
# AIE         574.0    0.389    0.488   0.0    0.00    0.0    1.0    1.0
# DST         569.0    0.871    1.099  -2.6    0.00    0.5    1.5    6.2
# IST         398.0    1.754    0.606   1.0    1.00    2.0    2.0    3.0
# NVP         207.0    0.720    0.990   0.0    0.00    0.0    1.0    3.0
# Talassemia  293.0    5.164    1.918   3.0    3.00    6.0    7.0    7.0

# %%
# quais as correlações entre as características numéricas?
data.corr()
# Out:
#             Idade    TDP    PAR     CS    ASJ    ECG    FCM    AIE    DST  \
# Idade       1.000  0.184  0.267 -0.104  0.198  0.211 -0.362  0.228  0.252
# TDP         0.184  1.000  0.056 -0.126  0.066  0.063 -0.327  0.427  0.278
# PAR         0.267  0.056  1.000  0.057  0.112  0.078 -0.113  0.149  0.163
# CS         -0.104 -0.126  0.057  1.000 -0.008  0.114  0.279 -0.076  0.035
# ASJ         0.198  0.066  0.112 -0.008  1.000  0.111 -0.019  0.024  0.038
# ECG         0.211  0.063  0.078  0.114  0.111  1.000  0.057  0.007  0.145
# FCM        -0.362 -0.327 -0.113  0.279 -0.019  0.057  1.000 -0.371 -0.120
# AIE         0.228  0.427  0.149 -0.076  0.024  0.007 -0.371  1.000  0.381
# DST         0.252  0.278  0.163  0.035  0.038  0.145 -0.120  0.381  1.000
# IST         0.110  0.210  0.046 -0.049  0.046 -0.056 -0.341  0.320  0.432
# NVP         0.371  0.190  0.094  0.014  0.170  0.210 -0.217  0.107  0.268
# Talassemia  0.113  0.404  0.065 -0.193  0.101 -0.052 -0.347  0.306  0.276
#
#               IST    NVP  Talassemia
# Idade       0.110  0.371       0.113
# TDP         0.210  0.190       0.404
# PAR         0.046  0.094       0.065
# CS         -0.049  0.014      -0.193
# ASJ         0.046  0.170       0.101
# ECG        -0.056  0.210      -0.052
# FCM        -0.341 -0.217      -0.347
# AIE         0.320  0.107       0.306
# DST         0.432  0.268       0.276
# IST         1.000  0.099       0.296
# NVP         0.099  1.000       0.318
# Talassemia  0.296  0.318       1.000

# %%
# show variable correlation which is more than 0.6 (positive or negative)
corr = data.corr()
corr[corr != 1][abs(corr) > 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.groupby('Diagnóstico').mean()
# Out:
#               Idade    TDP      PAR       CS    ASJ    ECG      FCM    AIE  \
# Diagnóstico
# A            50.806  2.798  129.730  231.532  0.115  0.555  148.413  0.131
# P            55.914  3.623  134.439  176.636  0.230  0.649  127.096  0.590
#
#                DST    IST    NVP  Talassemia
# Diagnóstico
# A            0.411  1.464  0.294       3.992
# P            1.234  1.908  1.194       6.000
