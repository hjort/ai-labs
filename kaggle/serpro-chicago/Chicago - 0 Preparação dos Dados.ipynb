# %%
import pandas as pd
import numpy as np

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Manipular dados de entrada

# %% [markdown]
# ### 1. Dados de crimes

# %%
# carregar dados
data = pd.read_csv('data/chicagoCrimes10k.csv.bz2', sep=',', encoding='UTF-8') #, index_col='ID')

# embaralhar dados
data = data.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data.shape)

# mostrar exemplos de dados
#data.head()
# Out:
# (9999, 22)

# %%
# remover colunas desnecessárias
data.drop(['X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Location'], axis=1, inplace=True)
#data.head()

# %%
# modificar nomes das colunas
cols = {}
for col in data.columns:
    newcol = col.replace(' ', '_')
    cols[col] = newcol
cols['Date'] = 'Date_Time'
data.rename(columns=cols, inplace=True)
#data.head()

# %%
# alterar valores dos booleanos
for col in ['Arrest', 'Domestic']:
    data[col] = data[col].map({True: 'YES', False: 'NO'})

# %%
# alterar os IDs dos registros
data['ID'] -= 21689

# %%
# definir campo chave
data.set_index('ID', inplace=True)

# %%
data.head()
# Out:
#         Case_Number               Date_Time                Block  IUCR  \
# ID
# 9923063    HY133182  01/29/2015 04:53:14 PM      029XX E 87TH ST  1811
# 9927630    HY138122  01/29/2015 09:13:39 PM   044XX S PULASKI RD  1150
# 9920228    HY130226  01/26/2015 10:30:42 AM  013XX W BELMONT AVE  1310
# 9932413    HY142247  02/06/2015 05:40:54 PM   020XX N LAWLER AVE  0560
# 9917884    HY128631  01/25/2015 08:30:38 PM    021XX N MAJOR AVE  2826
#
#                Primary_Type                     Description  \
# ID
# 9923063           NARCOTICS    POSS: CANNABIS 30GMS OR LESS
# 9927630  DECEPTIVE PRACTICE               CREDIT CARD FRAUD
# 9920228     CRIMINAL DAMAGE                     TO PROPERTY
# 9932413             ASSAULT                          SIMPLE
# 9917884       OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS
#
#                    Location_Description Arrest Domestic  Beat  District  Ward  \
# ID
# 9923063                          STREET    YES       NO   423       4.0    10
# 9927630                DEPARTMENT STORE     NO       NO   821       8.0    14
# 9920228  PARKING LOT/GARAGE(NON.RESID.)     NO       NO  1933      19.0    32
# 9932413                       APARTMENT     NO       NO  2522      25.0    31
# 9917884                       RESIDENCE     NO       NO  2515      25.0    29
#
#          Community_Area FBI_Code  Latitude  Longitude
# ID
# 9923063              46       18   41.7372   -87.5531
# 9927630              57       11   41.8124   -87.7236
# 9920228               6       14   41.9397   -87.6625
# 9932413              19      08A   41.9176   -87.7520
# 9917884              19       26   41.9185   -87.7681

# %%
# definir colunas como categóricas
for cols in ['Block', 'IUCR', 'Primary_Type', 'Description', 'Location_Description',
             'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community_Area', 'FBI_Code']:
    data[cols] = data[cols].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9999 entries, 9923063 to 9932108
# Data columns (total 16 columns):
# Case_Number             9999 non-null object
# Date_Time               9999 non-null object
# Block                   9999 non-null category
# IUCR                    9999 non-null category
# Primary_Type            9999 non-null category
# Description             9999 non-null category
# Location_Description    9993 non-null category
# Arrest                  9999 non-null category
# Domestic                9999 non-null category
# Beat                    9999 non-null category
# District                9837 non-null category
# Ward                    9999 non-null category
# Community_Area          9999 non-null category
# FBI_Code                9999 non-null category
# Latitude                9837 non-null float64
# Longitude               9837 non-null float64
# dtypes: category(12), float64(2), object(2)
# memory usage: 718.9+ KB

# %%
data.describe()
# Out:
#         Latitude  Longitude
# count  9837.0000  9837.0000
# mean     41.8426   -87.6741
# std       0.0860     0.0600
# min      41.6451   -87.9065
# 25%      41.7685   -87.7195
# 50%      41.8587   -87.6701
# 75%      41.9056   -87.6293
# max      42.0226   -87.5248

# %%
data.describe(include=['O'])
# Out:
#        Case_Number               Date_Time
# count         9999                    9999
# unique        9999                    9572
# top       HY140645  01/23/2015 11:00:40 PM
# freq             1                       3

# %%
data.describe(include=['category'])
# Out:
#                    Block  IUCR Primary_Type Description Location_Description  \
# count               9999  9999         9999        9999                 9993
# unique              6518   213           27         199                   91
# top     001XX N STATE ST  0820        THEFT      SIMPLE               STREET
# freq                  34   933         2034        1112                 2488
#
#        Arrest Domestic  Beat  District  Ward  Community_Area FBI_Code
# count    9999     9999  9999    9837.0  9999            9999     9999
# unique      2        2   274      22.0    50              77       25
# top        NO       NO   511      11.0    28              25       06
# freq     7071     8476   101     758.0   533             699     2034

# %% [markdown]
# ### Dados de temperatura

# %%
# carregar dados
data2 = pd.read_csv('data/chicagoAllWeather.csv.bz2', sep=',', index_col='date')

# embaralhar dados
data2 = data2.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data2.shape)

# mostrar exemplos de dados
data2.head()
# Out:
# (5162, 6)
#           month  day  year  maxTemp  meanTemp  minTemp
# date
# 5/6/13        5    6  2013     71.0      61.0     50.0
# 12/14/07     12   14  2007     28.0      23.0     18.0
# 10/26/14     10   26  2014     64.0      53.0     42.0
# 1/18/01       1   18  2001     30.0      24.0     19.0
# 11/2/04      11    2  2004     48.0      47.0     45.0

# %%
# remover colunas desnecessárias
data2.drop(['month', 'day', 'year'], axis=1, inplace=True)
data2.head()
# Out:
#           maxTemp  meanTemp  minTemp
# date
# 5/6/13       71.0      61.0     50.0
# 12/14/07     28.0      23.0     18.0
# 10/26/14     64.0      53.0     42.0
# 1/18/01      30.0      24.0     19.0
# 11/2/04      48.0      47.0     45.0

# %%
data2.head()
# Out:
#           maxTemp  meanTemp  minTemp
# date
# 5/6/13       71.0      61.0     50.0
# 12/14/07     28.0      23.0     18.0
# 10/26/14     64.0      53.0     42.0
# 1/18/01      30.0      24.0     19.0
# 11/2/04      48.0      47.0     45.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5162 entries, 5/6/13 to 12/12/09
# Data columns (total 3 columns):
# maxTemp     5149 non-null float64
# meanTemp    5149 non-null float64
# minTemp     5149 non-null float64
# dtypes: float64(3)
# memory usage: 141.1+ KB

# %%
data2.describe()
# Out:
#         maxTemp   meanTemp    minTemp
# count  5149.000  5149.0000  5149.0000
# mean     58.871    50.3104    41.4813
# std      21.483    19.9302    19.0207
# min      -2.000    -9.0000   -18.0000
# 25%      41.000    34.0000    28.0000
# 50%      61.000    51.0000    42.0000
# 75%      78.000    68.0000    57.0000
# max     103.000    93.0000    82.0000

# %% [markdown]
# ### Dados de censo

# %%
# carregar dados
data3 = pd.read_csv('data/chicagoCensus.csv.bz2', sep=',', encoding='UTF-8') #, index_col='ID')

# embaralhar dados
data3 = data3.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data3.shape)

# mostrar exemplos de dados
data3.head()
# Out:
# (78, 9)
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 67                   68.0           Englewood                         3.8
# 63                   64.0            Clearing                         2.7
# 50                   51.0       South Deering                         4.0
# 12                   13.0          North Park                         3.9
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 67                              46.6                         28.0
# 63                               8.9                          9.5
# 50                              29.2                         16.3
# 12                              13.2                          9.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 67                                          28.5
# 63                                          18.8
# 50                                          21.0
# 12                                          14.4
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               27.5               23939            39.0
# 67                              42.5               11888            94.0
# 63                              37.6               25113            29.0
# 50                              39.5               14685            65.0
# 12                              39.0               26576            33.0

# %%
# inserir valores faltantes
data3.loc[data3['Community Area Number'].isnull(), 'Community Area Number'] = 0
data3.fillna(0, inplace=True)

# %%
# alterar tipo de dados das colunas
for cols in ['Community Area Number', 'HARDSHIP INDEX']:
    data3[cols] = data3[cols].astype('int64')

# %%
# definir campo chave
data3.set_index('Community Area Number', inplace=True)

# %%
data3.tail()
# Out:
#                           COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# Community Area Number
# 0                                     CHICAGO                         4.7
# 48                            Calumet Heights                         2.1
# 42                                   Woodlawn                         2.9
# 76                                     O'Hare                         3.6
# 69                     Greater Grand Crossing                         3.6
#
#                        PERCENT HOUSEHOLDS BELOW POVERTY  \
# Community Area Number
# 0                                                  19.7
# 48                                                 11.5
# 42                                                 30.7
# 76                                                 15.4
# 69                                                 29.6
#
#                        PERCENT AGED 16+ UNEMPLOYED  \
# Community Area Number
# 0                                             12.9
# 48                                            20.0
# 42                                            23.4
# 76                                             7.1
# 69                                            23.0
#
#                        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# Community Area Number
# 0                                                              19.5
# 48                                                             11.0
# 42                                                             16.5
# 76                                                             10.9
# 69                                                             16.5
#
#                        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   \
# Community Area Number
# 0                                                  33.5               28202
# 48                                                 44.0               28887
# 42                                                 36.1               18672
# 76                                                 30.3               25828
# 69                                                 41.0               17285
#
#                        HARDSHIP INDEX
# Community Area Number
# 0                                   0
# 48                                 38
# 42                                 58
# 76                                 24
# 69                                 66

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 1 to 69
# Data columns (total 8 columns):
# COMMUNITY AREA NAME                             78 non-null object
# PERCENT OF HOUSING CROWDED                      78 non-null float64
# PERCENT HOUSEHOLDS BELOW POVERTY                78 non-null float64
# PERCENT AGED 16+ UNEMPLOYED                     78 non-null float64
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    78 non-null float64
# PERCENT AGED UNDER 18 OR OVER 64                78 non-null float64
# PER CAPITA INCOME                               78 non-null int64
# HARDSHIP INDEX                                  78 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# ## Gerar dados de treino e de teste

# %%
# dividir os dados de treino e teste
divisao = int(data.shape[0] * 0.85)
train = data[:divisao]
test = data[divisao:]
print(train.shape, test.shape)
# Out:
# (8499, 16) (1500, 16)

# %%
train.head()
# Out:
#         Case_Number               Date_Time                Block  IUCR  \
# ID
# 9923063    HY133182  01/29/2015 04:53:14 PM      029XX E 87TH ST  1811
# 9927630    HY138122  01/29/2015 09:13:39 PM   044XX S PULASKI RD  1150
# 9920228    HY130226  01/26/2015 10:30:42 AM  013XX W BELMONT AVE  1310
# 9932413    HY142247  02/06/2015 05:40:54 PM   020XX N LAWLER AVE  0560
# 9917884    HY128631  01/25/2015 08:30:38 PM    021XX N MAJOR AVE  2826
#
#                Primary_Type                     Description  \
# ID
# 9923063           NARCOTICS    POSS: CANNABIS 30GMS OR LESS
# 9927630  DECEPTIVE PRACTICE               CREDIT CARD FRAUD
# 9920228     CRIMINAL DAMAGE                     TO PROPERTY
# 9932413             ASSAULT                          SIMPLE
# 9917884       OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS
#
#                    Location_Description Arrest Domestic  Beat District Ward  \
# ID
# 9923063                          STREET    YES       NO   423      4.0   10
# 9927630                DEPARTMENT STORE     NO       NO   821      8.0   14
# 9920228  PARKING LOT/GARAGE(NON.RESID.)     NO       NO  1933     19.0   32
# 9932413                       APARTMENT     NO       NO  2522     25.0   31
# 9917884                       RESIDENCE     NO       NO  2515     25.0   29
#
#         Community_Area FBI_Code  Latitude  Longitude
# ID
# 9923063             46       18   41.7372   -87.5531
# 9927630             57       11   41.8124   -87.7236
# 9920228              6       14   41.9397   -87.6625
# 9932413             19      08A   41.9176   -87.7520
# 9917884             19       26   41.9185   -87.7681

# %%
test.head()
# Out:
#         Case_Number               Date_Time                   Block  IUCR  \
# ID
# 9918529    HY129084  01/25/2015 07:15:45 PM       0000X W MONROE ST  0870
# 9925380    HY134467  01/30/2015 08:30:10 AM         063XX W 64TH PL  0620
# 9928362    HY138953  02/04/2015 01:49:53 AM  054XX S HYDE PARK BLVD  0820
# 9922396    HY132485  01/29/2015 06:15:42 AM        003XX W ADAMS ST  0560
# 9931676    HY141605  02/05/2015 10:30:40 PM    030XX W WABANSIA AVE  1320
#
#             Primary_Type     Description    Location_Description Arrest  \
# ID
# 9918529            THEFT  POCKET-PICKING                SIDEWALK     NO
# 9925380         BURGLARY  UNLAWFUL ENTRY               APARTMENT     NO
# 9928362            THEFT  $500 AND UNDER  VEHICLE NON-COMMERCIAL     NO
# 9922396          ASSAULT          SIMPLE       CONVENIENCE STORE     NO
# 9931676  CRIMINAL DAMAGE      TO VEHICLE                  STREET     NO
#
#         Domestic  Beat District Ward Community_Area FBI_Code  Latitude  \
# ID
# 9918529       NO   112      1.0   42             32       06   41.8808
# 9925380       NO   812      8.0   13             64       05   41.7749
# 9928362      YES   234      2.0    5             41       06   41.7955
# 9922396       NO   122      1.0    2             32      08A   41.8795
# 9931676       NO  1421     14.0   26             23       14   41.9121
#
#          Longitude
# ID
# 9918529   -87.6284
# 9925380   -87.7800
# 9928362   -87.5838
# 9922396   -87.6358
# 9931676   -87.7033

# %% [markdown]
# ## Gerar dados de exemplo

# %%
example = test[['Arrest']]
example['Arrest'] = example.index.map(lambda x: 'NO' if (x % 3 == 0) else 'YES')
example.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Arrest
# ID
# 9918529    YES
# 9925380     NO
# 9928362     NO
# 9922396    YES
# 9931676    YES

# %%
example.describe()
# Out:
#        Arrest
# count    1500
# unique      2
# top       YES
# freq     1030

# %% [markdown]
# ## Gerar arquivos CSV

# %%
# definir parâmetros
file_prefix = 'chicago'
target_column = 'Arrest'

# %%
# gerar arquivos CSV
train.to_csv(file_prefix + '-train.csv')
test.drop([target_column], axis=1).to_csv(file_prefix + '-test.csv')
test[[target_column]].to_csv(file_prefix + '-solution.csv')
example.to_csv(file_prefix + '-example.csv')

# %%
# gerar arquivos adicionais (de apoio)
data2.to_csv(file_prefix + '-weather.csv')
data3.to_csv(file_prefix + '-census.csv')

# %%
# !head chicago-*.csv
# Out:
# ==> chicago-census.csv <==
# Community Area Number,COMMUNITY AREA NAME,PERCENT OF HOUSING CROWDED,PERCENT HOUSEHOLDS BELOW POVERTY,PERCENT AGED 16+ UNEMPLOYED,PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA,PERCENT AGED UNDER 18 OR OVER 64,PER CAPITA INCOME ,HARDSHIP INDEX
# 1,Rogers Park,7.7,23.6,8.7,18.2,27.5,23939,39
# 68,Englewood,3.8,46.6,28.0,28.5,42.5,11888,94
# 64,Clearing,2.7,8.9,9.5,18.8,37.6,25113,29
# 51,South Deering,4.0,29.2,16.3,21.0,39.5,14685,65
# 13,North Park,3.9,13.2,9.9,14.4,39.0,26576,33
# 62,West Elsdon,11.1,15.6,16.7,37.0,37.7,15754,69
# 43,South Shore,2.8,31.1,20.0,14.0,35.7,19398,55
# 5,North Center,0.3,7.5,5.2,4.5,26.2,57123,6
# 77,Edgewater,4.1,18.2,9.2,9.7,23.8,33385,19
#
# ==> chicago-example.csv <==
# ID,Arrest
# 9918529,YES
# 9925380,NO
# 9928362,NO
# 9922396,YES
# 9931676,YES
# 9925698,NO
# 9916909,YES
# 9932852,YES
# 9932021,YES
#
# ==> chicago-solution.csv <==
# ID,Arrest
# 9918529,NO
# 9925380,NO
# 9928362,NO
# 9922396,NO
# 9931676,NO
# 9925698,YES
# 9916909,NO
# 9932852,YES
# 9932021,NO
#
# ==> chicago-test.csv <==
# ID,Case_Number,Date_Time,Block,IUCR,Primary_Type,Description,Location_Description,Domestic,Beat,District,Ward,Community_Area,FBI_Code,Latitude,Longitude
# 9918529,HY129084,01/25/2015 07:15:45 PM,0000X W MONROE ST,0870,THEFT,POCKET-PICKING,SIDEWALK,NO,112,1.0,42,32,06,41.880847277,-87.628449354
# 9925380,HY134467,01/30/2015 08:30:10 AM,063XX W 64TH PL,0620,BURGLARY,UNLAWFUL ENTRY,APARTMENT,NO,812,8.0,13,64,05,41.7748567,-87.780034183
# 9928362,HY138953,02/04/2015 01:49:53 AM,054XX S HYDE PARK BLVD,0820,THEFT,$500 AND UNDER,VEHICLE NON-COMMERCIAL,YES,234,2.0,5,41,06,41.795522755,-87.583812136
# 9922396,HY132485,01/29/2015 06:15:42 AM,003XX W ADAMS ST,0560,ASSAULT,SIMPLE,CONVENIENCE STORE,NO,122,1.0,2,32,08A,41.87947355,-87.635826915
# 9931676,HY141605,02/05/2015 10:30:40 PM,030XX W WABANSIA AVE,1320,CRIMINAL DAMAGE,TO VEHICLE,STREET,NO,1421,14.0,26,23,14,41.912083762,-87.703318332
# 9925698,HY135783,01/31/2015 08:10:25 PM,001XX W 71ST ST,1811,NARCOTICS,POSS: CANNABIS 30GMS OR LESS,STREET,NO,731,7.0,6,69,18,41.765340022,-87.627402169
# 9916909,HY127337,01/24/2015 04:00:55 PM,024XX W 66TH ST,0560,ASSAULT,SIMPLE,STREET,NO,832,8.0,15,66,08A,41.773897272,-87.68426737
# 9932852,HY142951,02/07/2015 09:25:55 AM,084XX S KILBOURN AVE,051B,ASSAULT,AGGRAVATED: OTHER FIREARM,STREET,NO,834,8.0,18,70,04A,41.740048165,-87.733601069
# 9932021,HY141742,02/05/2015 08:00:21 PM,025XX W 109TH PL,1360,CRIMINAL TRESPASS,TO VEHICLE,STREET,NO,2212,22.0,19,75,26,41.694595108,-87.68578295
#
# ==> chicago-train.csv <==
# ID,Case_Number,Date_Time,Block,IUCR,Primary_Type,Description,Location_Description,Arrest,Domestic,Beat,District,Ward,Community_Area,FBI_Code,Latitude,Longitude
# 9923063,HY133182,01/29/2015 04:53:14 PM,029XX E 87TH ST,1811,NARCOTICS,POSS: CANNABIS 30GMS OR LESS,STREET,YES,NO,423,4.0,10,46,18,41.737248771,-87.553057244
# 9927630,HY138122,01/29/2015 09:13:39 PM,044XX S PULASKI RD,1150,DECEPTIVE PRACTICE,CREDIT CARD FRAUD,DEPARTMENT STORE,NO,NO,821,8.0,14,57,11,41.812384669,-87.723609479
# 9920228,HY130226,01/26/2015 10:30:42 AM,013XX W BELMONT AVE,1310,CRIMINAL DAMAGE,TO PROPERTY,PARKING LOT/GARAGE(NON.RESID.),NO,NO,1933,19.0,32,6,14,41.939676482,-87.662542697
# 9932413,HY142247,02/06/2015 05:40:54 PM,020XX N LAWLER AVE,0560,ASSAULT,SIMPLE,APARTMENT,NO,NO,2522,25.0,31,19,08A,41.917645305,-87.752031914
# 9917884,HY128631,01/25/2015 08:30:38 PM,021XX N MAJOR AVE,2826,OTHER OFFENSE,HARASSMENT BY ELECTRONIC MEANS,RESIDENCE,NO,NO,2515,25.0,29,19,26,41.918515715,-87.76806968
# 9932180,HY141988,02/06/2015 03:02:25 PM,018XX S CARPENTER ST,2820,OTHER OFFENSE,TELEPHONE THREAT,RESIDENCE,NO,NO,1235,12.0,25,31,26,41.857251342,-87.653335798
# 9941048,HY151489,02/05/2015 09:00:10 PM,047XX S SPRINGFIELD AVE,0486,BATTERY,DOMESTIC BATTERY SIMPLE,APARTMENT,NO,NO,821,8.0,14,57,08B,41.807262259,-87.721248221
# 9933733,HY144287,02/08/2015 12:24:35 PM,122XX S ELIZABETH ST,1822,NARCOTICS,MANU/DEL:CANNABIS OVER 10 GMS,RESIDENCE,YES,NO,524,5.0,34,53,18,41.67110509,-87.652798567
# 9921212,HY131262,01/27/2015 11:40:14 PM,065XX S PARNELL AVE,2820,OTHER OFFENSE,TELEPHONE THREAT,APARTMENT,NO,NO,722,7.0,20,68,26,41.775817864,-87.638677951
#
# ==> chicago-weather.csv <==
# date,maxTemp,meanTemp,minTemp
# 5/6/13,71.0,61.0,50.0
# 12/14/07,28.0,23.0,18.0
# 10/26/14,64.0,53.0,42.0
# 1/18/01,30.0,24.0,19.0
# 11/2/04,48.0,47.0,45.0
# 12/31/03,42.0,34.0,25.0
# 11/20/03,64.0,50.0,35.0
# 3/23/01,50.0,42.0,33.0
# 3/25/04,62.0,60.0,57.0
