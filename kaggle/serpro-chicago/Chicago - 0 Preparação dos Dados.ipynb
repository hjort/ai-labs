# %%
import pandas as pd
import numpy as np

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', None)

# %%
# carregar dados
data = pd.read_csv('data/chicagoCrimes10k.csv.bz2', sep=',', encoding='UTF-8', index_col='ID')

# embaralhar dados
#data = data.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data.shape)

# mostrar exemplos de dados
data.head()
# Out:
# (9999, 21)
#         Case Number                    Date                 Block  IUCR  \
# ID
# 9955810    HY144797  02/08/2015 11:43:40 PM     081XX S COLES AVE  1811
# 9955861    HY144838  02/08/2015 11:41:42 PM      118XX S STATE ST  0486
# 9955801    HY144779  02/08/2015 11:30:22 PM   002XX S LARAMIE AVE  2026
# 9956197    HY144787  02/08/2015 11:30:23 PM       006XX E 67TH ST  1811
# 9955846    HY144829  02/08/2015 11:30:58 PM  0000X S MAYFIELD AVE  0610
#
#         Primary Type                   Description Location Description  \
# ID
# 9955810    NARCOTICS  POSS: CANNABIS 30GMS OR LESS               STREET
# 9955861      BATTERY       DOMESTIC BATTERY SIMPLE            APARTMENT
# 9955801    NARCOTICS                     POSS: PCP             SIDEWALK
# 9956197    NARCOTICS  POSS: CANNABIS 30GMS OR LESS               STREET
# 9955846     BURGLARY                FORCIBLE ENTRY            APARTMENT
#
#          Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  \
# ...

# %%
# remover colunas desnecessárias
data.drop(['X Coordinate', 'Y Coordinate', 'Year', 'Updated On',
           'Latitude', 'Longitude', 'Location'], axis=1, inplace=True)
data.head()
# Out:
#         Case Number                    Date                 Block  IUCR  \
# ID
# 9955810    HY144797  02/08/2015 11:43:40 PM     081XX S COLES AVE  1811
# 9955861    HY144838  02/08/2015 11:41:42 PM      118XX S STATE ST  0486
# 9955801    HY144779  02/08/2015 11:30:22 PM   002XX S LARAMIE AVE  2026
# 9956197    HY144787  02/08/2015 11:30:23 PM       006XX E 67TH ST  1811
# 9955846    HY144829  02/08/2015 11:30:58 PM  0000X S MAYFIELD AVE  0610
#
#         Primary Type                   Description Location Description  \
# ID
# 9955810    NARCOTICS  POSS: CANNABIS 30GMS OR LESS               STREET
# 9955861      BATTERY       DOMESTIC BATTERY SIMPLE            APARTMENT
# 9955801    NARCOTICS                     POSS: PCP             SIDEWALK
# 9956197    NARCOTICS  POSS: CANNABIS 30GMS OR LESS               STREET
# 9955846     BURGLARY                FORCIBLE ENTRY            APARTMENT
#
#          Arrest  Domestic  Beat  District  Ward  Community Area FBI Code
# ID
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9999 entries, 9955810 to 9937290
# Data columns (total 14 columns):
# Case Number             9999 non-null object
# Date                    9999 non-null object
# Block                   9999 non-null object
# IUCR                    9999 non-null object
# Primary Type            9999 non-null object
# Description             9999 non-null object
# Location Description    9993 non-null object
# Arrest                  9999 non-null bool
# Domestic                9999 non-null bool
# Beat                    9999 non-null int64
# District                9837 non-null float64
# Ward                    9999 non-null int64
# Community Area          9999 non-null int64
# FBI Code                9999 non-null object
# dtypes: bool(2), float64(1), int64(3), object(8)
# memory usage: 722.6+ KB

# %%
data.describe()
# Out:
#             Beat   District       Ward  Community Area
# count  9999.0000  9837.0000  9999.0000       9999.0000
# mean   1159.6181    11.3490    22.9541         37.4476
# std     695.7603     6.9455    13.6496         21.2749
# min     111.0000     1.0000     1.0000          1.0000
# 25%     613.0000     6.0000    11.0000         23.0000
# 50%    1031.0000    10.0000    23.0000         32.0000
# 75%    1711.0000    17.0000    34.0000         57.0000
# max    2535.0000    25.0000    50.0000         77.0000

# %%
data.describe(include=['O'])
# Out:
#        Case Number                    Date             Block  IUCR  \
# count         9999                    9999              9999  9999
# unique        9999                    9572              6518   213
# top       HY137342  02/08/2015 09:00:10 PM  001XX N STATE ST  0820
# freq             1                       3                34   933
#
#        Primary Type Description Location Description FBI Code
# count          9999        9999                 9993     9999
# unique           27         199                   91       25
# top           THEFT      SIMPLE               STREET       06
# freq           2034        1112                 2488     2034

# %% [raw]
# # converter campos float para int
# cols = data.dtypes[data.dtypes == 'float'].index
# cols = ['DepTime', 'ArrTime', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime',
#        'ArrDelay', 'DepDelay', 'Distance', 'TaxiIn', 'TaxiOut', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']
# data[cols].info()
# #data[cols] = data[cols].astype(int)
# #data[cols].head()

# %%
# criar coluna única com informação da data
data['FlightDate'] = pd.to_datetime(data[['Year', 'Month', 'DayofMonth']].rename(columns={'DayofMonth': 'Day'}))

# %%
# remover colunas derivadas da data
data.drop(['Year', 'Month', 'DayofMonth', 'DayOfWeek'], axis=1, inplace=True)

# %%
# arrumar ordem das colunas
cols = data.columns.values[:-1].tolist()
cols.insert(0, 'FlightDate')
data = data[cols]

# %% [raw]
# data.head()

# %% [raw]
# data.info()

# %%
# dividir os dados de treino e teste
divisao = int(data.shape[0] * 4 / 5)
train = data[:divisao]
test = data[divisao:]
print(train.shape, test.shape)

# %%
train.head()

# %%
test.head()

# %%
example = test[['IsDepDelayed']]
example['IsDepDelayed'] = example.index.map(lambda x: 'NO' if (x % 2 == 0) else 'YES')
example.head()

# %%
example.describe()

# %%
# gerar arquivos CSV
train.to_csv('airlines-train.csv')
test.drop(['IsDepDelayed'], axis=1).to_csv('airlines-test.csv')
test[['IsDepDelayed']].to_csv('airlines-solution.csv')
example.to_csv('airlines-example.csv')

# %%
# !head airlines-*.csv
