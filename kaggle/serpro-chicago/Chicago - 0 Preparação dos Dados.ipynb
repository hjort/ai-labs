# %%
import pandas as pd
import numpy as np

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Manipular dados de entrada

# %% [markdown]
# ### 1. Dados de crimes

# %%
# carregar dados
data = pd.read_csv('data/chicagoCrimes10k.csv.bz2', sep=',', encoding='UTF-8') #, index_col='ID')

# embaralhar dados
data = data.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data.shape)

# mostrar exemplos de dados
#data.head()
# Out:
# (9999, 22)

# %%
# remover colunas desnecessárias
data.drop(['X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Location'], axis=1, inplace=True)
#data.head()

# %%
# modificar nomes das colunas
cols = {}
for col in data.columns:
    newcol = col.replace(' ', '_')
    cols[col] = newcol
cols['Date'] = 'Date_Time'
data.rename(columns=cols, inplace=True)
#data.head()

# %%
# alterar valores dos booleanos
for col in ['Arrest', 'Domestic']:
    data[col] = data[col].map({True: 'YES', False: 'NO'})

# %%
# alterar os IDs dos registros
data['ID'] -= 21689

# %%
# definir campo chave
data.set_index('ID', inplace=True)

# %%
data.head()
# Out:
#         Case_Number               Date_Time                Block  IUCR  \
# ID
# 9922073    HY132119  01/28/2015 06:29:34 PM     008XX W 115TH ST  1811
# 9928179    HY138758  02/03/2015 01:17:57 PM  061XX N WOLCOTT AVE  0820
# 9915870    HY125922  01/23/2015 03:18:30 PM    014XX S LUMBER ST  1350
# 9920228    HY130226  01/26/2015 10:30:42 AM  013XX W BELMONT AVE  1310
# 9920269    HY130368  01/27/2015 07:55:30 AM      028XX W 79TH ST  0560
#
#               Primary_Type                   Description  \
# ID
# 9922073          NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 9928179              THEFT                $500 AND UNDER
# 9915870  CRIMINAL TRESPASS             TO STATE SUP LAND
# 9920228    CRIMINAL DAMAGE                   TO PROPERTY
# 9920269            ASSAULT                        SIMPLE
#
#                       Location_Description Arrest Domestic  Beat  District  \
# ID
# 9922073                             STREET    YES       NO   524       5.0
# 9928179           SCHOOL, PUBLIC, BUILDING     NO       NO  2413      24.0
# 9915870  OTHER RAILROAD PROP / TRAIN DEPOT    YES       NO   124       1.0
# 9920228     PARKING LOT/GARAGE(NON.RESID.)     NO       NO  1933      19.0
# 9920269                             STREET     NO       NO   835       8.0
#
#          Ward  Community_Area FBI_Code  Latitude  Longitude
# ID
# 9922073    34              53       18   41.6850   -87.6435
# 9928179    40               2       06   41.9929   -87.6773
# 9915870     2              28       26   41.8636   -87.6352
# 9920228    32               6       14   41.9397   -87.6625
# 9920269    18              70      08A   41.7501   -87.6940

# %%
# definir colunas como categóricas
for cols in ['Block', 'IUCR', 'Primary_Type', 'Description', 'Location_Description',
             'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community_Area', 'FBI_Code']:
    data[cols] = data[cols].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9999 entries, 9922073 to 9928804
# Data columns (total 16 columns):
# Case_Number             9999 non-null object
# Date_Time               9999 non-null object
# Block                   9999 non-null category
# IUCR                    9999 non-null category
# Primary_Type            9999 non-null category
# Description             9999 non-null category
# Location_Description    9993 non-null category
# Arrest                  9999 non-null category
# Domestic                9999 non-null category
# Beat                    9999 non-null category
# District                9837 non-null category
# Ward                    9999 non-null category
# Community_Area          9999 non-null category
# FBI_Code                9999 non-null category
# Latitude                9837 non-null float64
# Longitude               9837 non-null float64
# dtypes: category(12), float64(2), object(2)
# memory usage: 718.9+ KB

# %%
data.describe()
# Out:
#         Latitude  Longitude
# count  9837.0000  9837.0000
# mean     41.8426   -87.6741
# std       0.0860     0.0600
# min      41.6451   -87.9065
# 25%      41.7685   -87.7195
# 50%      41.8587   -87.6701
# 75%      41.9056   -87.6293
# max      42.0226   -87.5248

# %%
data.describe(include=['O'])
# Out:
#        Case_Number               Date_Time
# count         9999                    9999
# unique        9999                    9572
# top       HY139542  01/24/2015 06:00:17 PM
# freq             1                       3

# %%
data.describe(include=['category'])
# Out:
#                    Block  IUCR Primary_Type Description Location_Description  \
# count               9999  9999         9999        9999                 9993
# unique              6518   213           27         199                   91
# top     001XX N STATE ST  0820        THEFT      SIMPLE               STREET
# freq                  34   933         2034        1112                 2488
#
#        Arrest Domestic  Beat  District  Ward  Community_Area FBI_Code
# count    9999     9999  9999    9837.0  9999            9999     9999
# unique      2        2   274      22.0    50              77       25
# top        NO       NO   511      11.0    28              25       06
# freq     7071     8476   101     758.0   533             699     2034

# %% [markdown]
# ### Dados de temperatura

# %%
# carregar dados
data2 = pd.read_csv('data/chicagoAllWeather.csv.bz2', sep=',', index_col='date')

# embaralhar dados
data2 = data2.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data2.shape)

# mostrar exemplos de dados
data2.head()
# Out:
# (5162, 6)
#           month  day  year  maxTemp  meanTemp  minTemp
# date
# 4/10/10       4   10  2010     74.0      56.0     38.0
# 2/25/01       2   25  2001     55.0      42.0     28.0
# 5/15/11       5   15  2011     46.0      44.0     41.0
# 9/29/14       9   29  2014     83.0      68.0     53.0
# 12/28/04     12   28  2004     41.0      32.0     24.0

# %%
# remover colunas desnecessárias
data2.drop(['month', 'day', 'year'], axis=1, inplace=True)
data2.head()
# Out:
#           maxTemp  meanTemp  minTemp
# date
# 4/10/10      74.0      56.0     38.0
# 2/25/01      55.0      42.0     28.0
# 5/15/11      46.0      44.0     41.0
# 9/29/14      83.0      68.0     53.0
# 12/28/04     41.0      32.0     24.0

# %%
data2.head()
# Out:
#           maxTemp  meanTemp  minTemp
# date
# 4/10/10      74.0      56.0     38.0
# 2/25/01      55.0      42.0     28.0
# 5/15/11      46.0      44.0     41.0
# 9/29/14      83.0      68.0     53.0
# 12/28/04     41.0      32.0     24.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5162 entries, 4/10/10 to 7/26/12
# Data columns (total 3 columns):
# maxTemp     5149 non-null float64
# meanTemp    5149 non-null float64
# minTemp     5149 non-null float64
# dtypes: float64(3)
# memory usage: 141.1+ KB

# %%
data2.describe()
# Out:
#         maxTemp   meanTemp    minTemp
# count  5149.000  5149.0000  5149.0000
# mean     58.871    50.3104    41.4813
# std      21.483    19.9302    19.0207
# min      -2.000    -9.0000   -18.0000
# 25%      41.000    34.0000    28.0000
# 50%      61.000    51.0000    42.0000
# 75%      78.000    68.0000    57.0000
# max     103.000    93.0000    82.0000

# %% [markdown]
# ### Dados de censo

# %%
# carregar dados
data3 = pd.read_csv('data/chicagoCensus.csv.bz2', sep=',', encoding='UTF-8') #, index_col='ID')

# embaralhar dados
data3 = data3.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data3.shape)

# mostrar exemplos de dados
data3.head()
# Out:
# (78, 9)
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 6                     7.0        Lincoln Park                         0.8
# 18                   19.0      Belmont Cragin                        10.8
# 11                   12.0         Forest Glen                         1.1
# 69                   70.0             Ashburn                         4.0
# 9                    10.0        Norwood Park                         2.0
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 6                               12.3                          5.1
# 18                              18.7                         14.6
# 11                               7.5                          6.8
# 69                              10.4                         11.7
# 9                                5.4                          9.0
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 6                                            3.6
# 18                                          37.3
# 11                                           4.9
# 69                                          17.7
# 9                                           11.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 6                               21.5               71551             2.0
# 18                              37.3               15461            70.0
# 11                              40.5               44164            11.0
# 69                              36.9               23482            37.0
# 9                               39.5               32875            21.0

# %%
# inserir valores faltantes
data3.loc[data3['Community Area Number'].isnull(), 'Community Area Number'] = 0
data3.fillna(0, inplace=True)

# %%
# alterar tipo de dados das colunas
for cols in ['Community Area Number', 'HARDSHIP INDEX']:
    data3[cols] = data3[cols].astype('int64')

# %%
# definir campo chave
data3.set_index('Community Area Number', inplace=True)

# %%
data3.tail()
# Out:
#                       COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# Community Area Number
# 37                            Fuller Park                         3.2
# 5                            North Center                         0.3
# 46                          South Chicago                         4.7
# 72                                Beverly                         0.9
# 42                               Woodlawn                         2.9
#
#                        PERCENT HOUSEHOLDS BELOW POVERTY  \
# Community Area Number
# 37                                                 51.2
# 5                                                   7.5
# 46                                                 29.8
# 72                                                  5.1
# 42                                                 30.7
#
#                        PERCENT AGED 16+ UNEMPLOYED  \
# Community Area Number
# 37                                            33.9
# 5                                              5.2
# 46                                            19.7
# 72                                             8.0
# 42                                            23.4
#
#                        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# Community Area Number
# 37                                                             26.6
# 5                                                               4.5
# 46                                                             26.6
# 72                                                              3.7
# 42                                                             16.5
#
#                        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   \
# Community Area Number
# 37                                                 44.9               10432
# 5                                                  26.2               57123
# 46                                                 41.1               16579
# 72                                                 40.5               39523
# 42                                                 36.1               18672
#
#                        HARDSHIP INDEX
# Community Area Number
# 37                                 97
# 5                                   6
# 46                                 75
# 72                                 12
# 42                                 58

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 7 to 42
# Data columns (total 8 columns):
# COMMUNITY AREA NAME                             78 non-null object
# PERCENT OF HOUSING CROWDED                      78 non-null float64
# PERCENT HOUSEHOLDS BELOW POVERTY                78 non-null float64
# PERCENT AGED 16+ UNEMPLOYED                     78 non-null float64
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    78 non-null float64
# PERCENT AGED UNDER 18 OR OVER 64                78 non-null float64
# PER CAPITA INCOME                               78 non-null int64
# HARDSHIP INDEX                                  78 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# ## Gerar dados de treino e de teste

# %%
# dividir os dados de treino e teste
divisao = int(data.shape[0] * 0.85)
train = data[:divisao]
test = data[divisao:]
print(train.shape, test.shape)
# Out:
# (8499, 16) (1500, 16)

# %%
train.head()
# Out:
#         Case_Number               Date_Time                Block  IUCR  \
# ID
# 9922073    HY132119  01/28/2015 06:29:34 PM     008XX W 115TH ST  1811
# 9928179    HY138758  02/03/2015 01:17:57 PM  061XX N WOLCOTT AVE  0820
# 9915870    HY125922  01/23/2015 03:18:30 PM    014XX S LUMBER ST  1350
# 9920228    HY130226  01/26/2015 10:30:42 AM  013XX W BELMONT AVE  1310
# 9920269    HY130368  01/27/2015 07:55:30 AM      028XX W 79TH ST  0560
#
#               Primary_Type                   Description  \
# ID
# 9922073          NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 9928179              THEFT                $500 AND UNDER
# 9915870  CRIMINAL TRESPASS             TO STATE SUP LAND
# 9920228    CRIMINAL DAMAGE                   TO PROPERTY
# 9920269            ASSAULT                        SIMPLE
#
#                       Location_Description Arrest Domestic  Beat District  \
# ID
# 9922073                             STREET    YES       NO   524      5.0
# 9928179           SCHOOL, PUBLIC, BUILDING     NO       NO  2413     24.0
# 9915870  OTHER RAILROAD PROP / TRAIN DEPOT    YES       NO   124      1.0
# 9920228     PARKING LOT/GARAGE(NON.RESID.)     NO       NO  1933     19.0
# 9920269                             STREET     NO       NO   835      8.0
#
#         Ward Community_Area FBI_Code  Latitude  Longitude
# ID
# 9922073   34             53       18   41.6850   -87.6435
# 9928179   40              2       06   41.9929   -87.6773
# 9915870    2             28       26   41.8636   -87.6352
# 9920228   32              6       14   41.9397   -87.6625
# 9920269   18             70      08A   41.7501   -87.6940

# %%
test.head()
# Out:
#         Case_Number               Date_Time                 Block  IUCR  \
# ID
# 9934020    HY144513  02/08/2015 05:30:47 PM  071XX S EAST END AVE  0486
# 9933471    HY143859  02/08/2015 01:55:35 AM   010XX N DEARBORN ST  0460
# 9932646    HY142651  02/07/2015 02:00:21 AM      017XX S STATE ST  1210
# 9930137    HY140334  02/05/2015 08:46:52 AM       035XX W 71ST ST  0910
# 9921675    HY131654  01/27/2015 10:00:18 PM    062XX S WHIPPLE ST  0820
#
#                 Primary_Type              Description  \
# ID
# 9934020              BATTERY  DOMESTIC BATTERY SIMPLE
# 9933471              BATTERY                   SIMPLE
# 9932646   DECEPTIVE PRACTICE  THEFT OF LABOR/SERVICES
# 9930137  MOTOR VEHICLE THEFT               AUTOMOBILE
# 9921675                THEFT           $500 AND UNDER
#
#                     Location_Description Arrest Domestic  Beat District Ward  \
# ID
# 9934020    RESIDENTIAL YARD (FRONT/BACK)     NO      YES   324      3.0    8
# 9933471                CONVENIENCE STORE     NO       NO  1824     18.0   42
# 9932646  POLICE FACILITY/VEH PARKING LOT    YES       NO   131      1.0    3
# 9930137    RESIDENTIAL YARD (FRONT/BACK)     NO       NO   831      8.0   18
# 9921675                           STREET     NO       NO   823      8.0   15
#
#         Community_Area FBI_Code  Latitude  Longitude
# ID
# 9934020             43      08B   41.7652   -87.5838
# 9933471              8      08B   41.9017   -87.6301
# 9932646             33       11   41.8584   -87.6274
# 9930137             66       07   41.7642   -87.7105
# 9921675             66       06   41.7798   -87.6994

# %% [markdown]
# ## Gerar dados de exemplo

# %%
example = test[['Arrest']]
example['Arrest'] = example.index.map(lambda x: 'NO' if (x % 3 == 0) else 'YES')
example.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Arrest
# ID
# 9934020     NO
# 9933471     NO
# 9932646     NO
# 9930137    YES
# 9921675     NO

# %%
example.describe()
# Out:
#        Arrest
# count    1500
# unique      2
# top       YES
# freq     1001

# %% [markdown]
# ## Gerar arquivos CSV

# %%
# gerar arquivos CSV
train.to_csv('chicago-train.csv')
test.drop(['Arrest'], axis=1).to_csv('chicago-test.csv')
test[['Arrest']].to_csv('chicago-solution.csv')
example.to_csv('chicago-example.csv')

# %%
# gerar arquivos adicionais (de apoio)
data2.to_csv('chicago-weather.csv')
data3.to_csv('chicago-census.csv')

# %%
# !head chicago-*.csv
# Out:
# ==> chicago-census.csv <==
# Community Area Number,COMMUNITY AREA NAME,PERCENT OF HOUSING CROWDED,PERCENT HOUSEHOLDS BELOW POVERTY,PERCENT AGED 16+ UNEMPLOYED,PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA,PERCENT AGED UNDER 18 OR OVER 64,PER CAPITA INCOME ,HARDSHIP INDEX
# 7,Lincoln Park,0.8,12.3,5.1,3.6,21.5,71551,2
# 19,Belmont Cragin,10.8,18.7,14.6,37.3,37.3,15461,70
# 12,Forest Glen,1.1,7.5,6.8,4.9,40.5,44164,11
# 70,Ashburn,4.0,10.4,11.7,17.7,36.9,23482,37
# 10,Norwood Park,2.0,5.4,9.0,11.5,39.5,32875,21
# 40,Washington Park,5.6,42.1,28.6,25.4,42.8,13785,88
# 58,Brighton Park,14.4,23.6,13.9,45.1,39.3,13089,84
# 74,Mount Greenwood,1.0,3.4,8.7,4.3,36.8,34381,16
# 45,Avalon Park,1.4,17.2,21.1,10.6,39.3,24454,41
#
# ==> chicago-example.csv <==
# ID,Arrest
# 9934020,NO
# 9933471,NO
# 9932646,NO
# 9930137,YES
# 9921675,NO
# 9916441,YES
# 9927469,YES
# 9931231,YES
# 9928574,YES
#
# ==> chicago-solution.csv <==
# ID,Arrest
# 9934020,NO
# 9933471,NO
# 9932646,YES
# 9930137,NO
# 9921675,NO
# 9916441,NO
# 9927469,NO
# 9931231,NO
# 9928574,YES
#
# ==> chicago-test.csv <==
# ID,Case_Number,Date_Time,Block,IUCR,Primary_Type,Description,Location_Description,Domestic,Beat,District,Ward,Community_Area,FBI_Code,Latitude,Longitude
# 9934020,HY144513,02/08/2015 05:30:47 PM,071XX S EAST END AVE,0486,BATTERY,DOMESTIC BATTERY SIMPLE,RESIDENTIAL YARD (FRONT/BACK),YES,324,3.0,8,43,08B,41.765201042,-87.583798605
# 9933471,HY143859,02/08/2015 01:55:35 AM,010XX N DEARBORN ST,0460,BATTERY,SIMPLE,CONVENIENCE STORE,NO,1824,18.0,42,8,08B,41.901677732,-87.630067977
# 9932646,HY142651,02/07/2015 02:00:21 AM,017XX S STATE ST,1210,DECEPTIVE PRACTICE,THEFT OF LABOR/SERVICES,POLICE FACILITY/VEH PARKING LOT,NO,131,1.0,3,33,11,41.858376151,-87.627356324
# 9930137,HY140334,02/05/2015 08:46:52 AM,035XX W 71ST ST,0910,MOTOR VEHICLE THEFT,AUTOMOBILE,RESIDENTIAL YARD (FRONT/BACK),NO,831,8.0,18,66,07,41.764160277,-87.710504009
# 9921675,HY131654,01/27/2015 10:00:18 PM,062XX S WHIPPLE ST,0820,THEFT,$500 AND UNDER,STREET,NO,823,8.0,15,66,06,41.779763767,-87.699357622
# 9916441,HY126668,01/24/2015 05:27:19 AM,001XX S KOSTNER AVE,031A,ROBBERY,ARMED: HANDGUN,SIDEWALK,NO,1113,11.0,28,26,03,41.878639151,-87.735556719
# 9927469,HY137968,02/01/2015 07:40:40 PM,003XX E ONTARIO ST,0910,MOTOR VEHICLE THEFT,AUTOMOBILE,PARKING LOT/GARAGE(NON.RESID.),NO,1834,18.0,42,8,07,41.893327441,-87.618579109
# 9931231,HY141390,02/05/2015 03:45:55 PM,021XX S RACINE AVE,0910,MOTOR VEHICLE THEFT,AUTOMOBILE,STREET,NO,1235,12.0,25,31,07,41.854262124,-87.656465458
# 9928574,HY139074,02/04/2015 06:20:30 AM,030XX N DRAKE AVE,1811,NARCOTICS,POSS: CANNABIS 30GMS OR LESS,RESIDENCE,NO,1412,14.0,35,21,18,41.93703865,-87.71625261
#
# ==> chicago-train.csv <==
# ID,Case_Number,Date_Time,Block,IUCR,Primary_Type,Description,Location_Description,Arrest,Domestic,Beat,District,Ward,Community_Area,FBI_Code,Latitude,Longitude
# 9922073,HY132119,01/28/2015 06:29:34 PM,008XX W 115TH ST,1811,NARCOTICS,POSS: CANNABIS 30GMS OR LESS,STREET,YES,NO,524,5.0,34,53,18,41.684955003,-87.643463604
# 9928179,HY138758,02/03/2015 01:17:57 PM,061XX N WOLCOTT AVE,0820,THEFT,$500 AND UNDER,"SCHOOL, PUBLIC, BUILDING",NO,NO,2413,24.0,40,2,06,41.992851029,-87.677280117
# 9915870,HY125922,01/23/2015 03:18:30 PM,014XX S LUMBER ST,1350,CRIMINAL TRESPASS,TO STATE SUP LAND,OTHER RAILROAD PROP / TRAIN DEPOT,YES,NO,124,1.0,2,28,26,41.863583401,-87.635217697
# 9920228,HY130226,01/26/2015 10:30:42 AM,013XX W BELMONT AVE,1310,CRIMINAL DAMAGE,TO PROPERTY,PARKING LOT/GARAGE(NON.RESID.),NO,NO,1933,19.0,32,6,14,41.939676482,-87.662542697
# 9920269,HY130368,01/27/2015 07:55:30 AM,028XX W 79TH ST,0560,ASSAULT,SIMPLE,STREET,NO,NO,835,8.0,18,70,08A,41.750068294,-87.694020956
# 9924615,HY134143,01/30/2015 02:15:58 PM,033XX S CARPENTER ST,0486,BATTERY,DOMESTIC BATTERY SIMPLE,RESIDENCE PORCH/HALLWAY,NO,YES,913,9.0,11,60,08B,41.833636925,-87.652400585
# 9932854,HY143034,02/07/2015 11:00:44 AM,101XX S MAY ST,0486,BATTERY,DOMESTIC BATTERY SIMPLE,RESIDENCE,NO,YES,2232,22.0,34,73,08B,41.709455301,-87.651559225
# 9917095,HY127635,01/24/2015 06:30:36 PM,002XX W WASHINGTON ST,0820,THEFT,$500 AND UNDER,PARKING LOT/GARAGE(NON.RESID.),NO,NO,122,1.0,42,32,06,41.883101015,-87.634403021
# 9935571,HY146077,02/08/2015 03:00:42 AM,031XX N SAWYER AVE,0486,BATTERY,DOMESTIC BATTERY SIMPLE,APARTMENT,NO,YES,1412,14.0,35,21,08B,41.938686977,-87.708970346
#
# ==> chicago-weather.csv <==
# date,maxTemp,meanTemp,minTemp
# 4/10/10,74.0,56.0,38.0
# 2/25/01,55.0,42.0,28.0
# 5/15/11,46.0,44.0,41.0
# 9/29/14,83.0,68.0,53.0
# 12/28/04,41.0,32.0,24.0
# 6/13/08,82.0,74.0,65.0
# 3/27/12,74.0,57.0,40.0
# 10/27/08,47.0,40.0,33.0
# 10/14/09,48.0,45.0,42.0
