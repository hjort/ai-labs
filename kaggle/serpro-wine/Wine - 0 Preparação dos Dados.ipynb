# %%
import pandas as pd
import numpy as np

# %%
# carregar dados
data = pd.read_csv('winequality-white.csv', sep=';')

# embaralhar dados
data = data.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data.shape)

# mostrar exemplos de dados
data.head()
# Out:
# (4898, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3472                 24.0                 131.0  0.99284  3.30       0.59
# 3455                 29.0                  86.0  0.98926  2.90       0.38
# 3322                 30.0                 105.0  0.98995  3.48       0.52
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 2123                 47.0                 154.0  0.99670  3.05       0.38
#
#       alcohol  quality
# 3472     10.5        6
# 3455     12.2        6
# 3322     12.5        7
# 4896     12.8        7
# 2123      9.0        5

# %%
# renomear coluna índice
data.index.names = ['wine']

# %%
# modificar nomes das colunas

cols = {}
for col in data.columns:
    newcol = col.lower().replace(' ', '_')
    cols[col] = newcol
    #print(col, '=>', newcol)

#print(type(cols), cols)

data.rename(columns=cols, inplace=True)

# %% [raw]
# # aumentar a precisão da coluna alvo
# data.quality = round(data.quality + 1e-3, 2)

# %%
data.quality = data.quality.map(lambda x: 'good' if x > 6 else 'bad')

# %%
data['quality'].describe()
# Out:
# count     4898
# unique       2
# top        bad
# freq      3838
# Name: quality, dtype: object

# %%
# exibir dados
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0  0.99284  3.30       0.59
# 3455                 29.0                  86.0  0.98926  2.90       0.38
# 3322                 30.0                 105.0  0.98995  3.48       0.52
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 2123                 47.0                 154.0  0.99670  3.05       0.38
#
#       alcohol quality
# wine
# 3472     10.5     bad
# 3455     12.2     bad
# 3322     12.5    good
# 4896     12.8    good
# 2123      9.0     bad

# %%
# dividir os dados de treino e teste

divisao = int(data.shape[0] * 2 / 3)

train = data[:divisao]
test = data[divisao:]

print(train.shape, test.shape)
# Out:
# (3265, 12) (1633, 12)

# %%
train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0  0.99284  3.30       0.59
# 3455                 29.0                  86.0  0.98926  2.90       0.38
# 3322                 30.0                 105.0  0.98995  3.48       0.52
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 2123                 47.0                 154.0  0.99670  3.05       0.38
#
#       alcohol quality
# wine
# 3472     10.5     bad
# 3455     12.2     bad
# 3322     12.5    good
# 4896     12.8    good
# 2123      9.0     bad

# %%
test.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 1214            9.7              0.24         0.45             1.2      0.033
# 727             7.0              0.21         0.34             8.0      0.057
# 481             5.9              0.36         0.41             1.3      0.047
# 1308            9.2              0.15         0.68             1.6      0.046
# 4087            6.5              0.21         0.42             1.1      0.059
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 1214                 11.0                  59.0   0.9926  2.74       0.47
# 727                  19.0                 101.0   0.9954  2.99       0.59
# 481                  45.0                 104.0   0.9917  3.33       0.51
# 1308                 22.0                 130.0   0.9948  3.02       0.45
# 4087                 33.0                 101.0   0.9927  3.12       0.38
#
#       alcohol quality
# wine
# 1214     10.8     bad
# 727       9.4     bad
# 481      10.6     bad
# 1308     10.4     bad
# 4087      9.7     bad

# %%
example = test[['quality']]
#example['quality'] = example.index.map(lambda x: float(x % 7 + 3))
example['quality'] = example.index.map(lambda x: 'good' if (x % 2 == 0) else 'bad')
example.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      quality
# wine
# 1214    good
# 727      bad
# 481      bad
# 1308    good
# 4087     bad

# %%
example.describe()
# Out:
#        quality
# count     1633
# unique       2
# top       good
# freq       817

# %%
train.to_csv('wine-train.csv')

test.drop(['quality'], axis=1).to_csv('wine-test.csv')
test[['quality']].to_csv('wine-solution.csv')

example.to_csv('wine-example.csv')

# %%
# !head wine-*.csv
# Out:
# ==> wine-example.csv <==
# wine,quality
# 1214,good
# 727,bad
# 481,bad
# 1308,good
# 4087,bad
# 619,bad
# 4669,bad
# 874,good
# 2337,bad
#
# ==> wine-solution.csv <==
# wine,quality
# 1214,bad
# 727,bad
# 481,bad
# 1308,bad
# 4087,bad
# 619,bad
# 4669,bad
# 874,bad
# 2337,bad
#
# ==> wine-test.csv <==
# wine,fixed_acidity,volatile_acidity,citric_acid,residual_sugar,chlorides,free_sulfur_dioxide,total_sulfur_dioxide,density,ph,sulphates,alcohol
# 1214,9.7,0.24,0.45,1.2,0.033,11.0,59.0,0.9926,2.74,0.47,10.8
# 727,7.0,0.21,0.34,8.0,0.057,19.0,101.0,0.9954,2.99,0.59,9.4
# 481,5.9,0.36,0.41,1.3,0.047,45.0,104.0,0.9917,3.33,0.51,10.6
# 1308,9.2,0.15,0.68,1.6,0.046,22.0,130.0,0.9948,3.02,0.45,10.4
# 4087,6.5,0.21,0.42,1.1,0.059,33.0,101.0,0.9927,3.12,0.38,9.7
# 619,7.4,0.19,0.3,1.4,0.057,33.0,135.0,0.993,3.12,0.5,9.6
# 4669,5.9,0.44,0.33,1.2,0.049,12.0,117.0,0.99134,3.46,0.44,11.5
# 874,7.7,0.15,0.29,1.3,0.029,10.0,64.0,0.9932,3.35,0.39,10.1
# 2337,6.5,0.28,0.35,9.8,0.067,61.0,180.0,0.9972,3.15,0.57,9.0
#
# ==> wine-train-filtered-scaled.csv <==
# wine,fixed_acidity,volatile_acidity,citric_acid,residual_sugar,chlorides,free_sulfur_dioxide,total_sulfur_dioxide,density,ph,sulphates,alcohol,quality
# 4783,0.3544303797468354,0.23783783783783785,0.4065040650406504,0.1763803680981595,0.12811387900355872,0.1254355400696864,0.27378190255220414,0.19838056680161742,0.2777777777777777,0.3604651162790698,0.14876033057851235,0.0
# 2382,0.37974683544303794,0.07567567567567568,0.22764227642276424,0.05828220858895705,0.07117437722419931,0.041811846689895474,0.22737819025522038,0.12261422787738496,0.46296296296296324,0.27906976744186046,0.39669421487603307,1.0
# 2303,0.37974683544303794,0.3891891891891892,0.14634146341463414,0.17177914110429449,0.14946619217081852,0.08362369337979095,0.27146171693735494,0.2003084634663601,0.4537037037037037,0.30232558139534876,0.18181818181818166,0.0
# 4254,0.4556962025316455,0.22702702702702704,0.19512195121951217,0.14263803680981596,0.17437722419928828,0.08013937282229966,0.24593967517401388,0.16502795450163887,0.37962962962962976,0.27906976744186046,0.47933884297520657,0.0
