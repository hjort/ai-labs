# %%
import pandas as pd
import numpy as np

# %%
# carregar dados
data = pd.read_csv('winequality-white.csv', sep=';')

# embaralhar dados
data = data.sample(frac=1)

# mostrar quantidade de linhas e colunas
print(data.shape)

# mostrar exemplos de dados
data.head()
# Out:
# (4898, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4783            6.7              0.30         0.50            12.1      0.045
# 2382            6.9              0.15         0.28             4.4      0.029
# 2303            6.9              0.44         0.18            11.8      0.051
# 4254            7.5              0.29         0.24             9.9      0.058
# 1593            8.6              0.16         0.49             7.3      0.043
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4783                 38.0                 127.0  0.99740  3.04       0.53
# 2382                 14.0                 107.0  0.99347  3.24       0.46
# 2303                 26.0                 126.0  0.99750  3.23       0.48
# 4254                 25.0                 115.0  0.99567  3.15       0.46
# 1593                  9.0                  63.0  0.99530  3.13       0.59
#
#       alcohol  quality
# 4783      8.9        6
# 2382     10.4        8
# 2303      9.1        5
# 4254     10.9        5
# 1593     10.5        6

# %%
# renomear coluna índice
data.index.names = ['wine']

# %%
# modificar nomes das colunas

cols = {}
for col in data.columns:
    newcol = col.lower().replace(' ', '_')
    cols[col] = newcol
    #print(col, '=>', newcol)

#print(type(cols), cols)

data.rename(columns=cols, inplace=True)

# %% [raw]
# # aumentar a precisão da coluna alvo
# data.quality = round(data.quality + 1e-3, 2)

# %%
data.quality = data.quality.map(lambda x: 'good' if x > 6 else 'bad')

# %%
data['quality'].describe()
# Out:
# count     4898
# unique       2
# top        bad
# freq      3838
# Name: quality, dtype: object

# %%
# exibir dados
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 4783            6.7              0.30         0.50            12.1      0.045
# 2382            6.9              0.15         0.28             4.4      0.029
# 2303            6.9              0.44         0.18            11.8      0.051
# 4254            7.5              0.29         0.24             9.9      0.058
# 1593            8.6              0.16         0.49             7.3      0.043
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 4783                 38.0                 127.0  0.99740  3.04       0.53
# 2382                 14.0                 107.0  0.99347  3.24       0.46
# 2303                 26.0                 126.0  0.99750  3.23       0.48
# 4254                 25.0                 115.0  0.99567  3.15       0.46
# 1593                  9.0                  63.0  0.99530  3.13       0.59
#
#       alcohol quality
# wine
# 4783      8.9     bad
# 2382     10.4    good
# 2303      9.1     bad
# 4254     10.9     bad
# 1593     10.5     bad

# %%
# dividir os dados de treino e teste

divisao = int(data.shape[0] * 2 / 3)

train = data[:divisao]
test = data[divisao:]

print(train.shape, test.shape)
# Out:
# (3265, 12) (1633, 12)

# %%
train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 4783            6.7              0.30         0.50            12.1      0.045
# 2382            6.9              0.15         0.28             4.4      0.029
# 2303            6.9              0.44         0.18            11.8      0.051
# 4254            7.5              0.29         0.24             9.9      0.058
# 1593            8.6              0.16         0.49             7.3      0.043
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 4783                 38.0                 127.0  0.99740  3.04       0.53
# 2382                 14.0                 107.0  0.99347  3.24       0.46
# 2303                 26.0                 126.0  0.99750  3.23       0.48
# 4254                 25.0                 115.0  0.99567  3.15       0.46
# 1593                  9.0                  63.0  0.99530  3.13       0.59
#
#       alcohol quality
# wine
# 4783      8.9     bad
# 2382     10.4    good
# 2303      9.1     bad
# 4254     10.9     bad
# 1593     10.5     bad

# %%
test.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3123            5.5              0.18         0.22             5.5      0.037
# 3903            5.8              0.27         0.26             3.5      0.071
# 3104            7.6              0.21         0.49             2.5      0.047
# 4190            7.0              0.22         0.30             1.4      0.040
# 2133            8.3              0.24         0.27             2.1      0.030
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3123                 10.0                  86.0  0.99156  3.46       0.44
# 3903                 26.0                  69.0  0.98994  3.10       0.38
# 3104                 20.0                 130.0  0.99178  3.15       0.48
# 4190                 14.0                  63.0  0.98985  3.20       0.33
# 2133                 22.0                 162.0  0.99140  2.99       0.68
#
#       alcohol quality
# wine
# 3123     12.2     bad
# 3903     11.5     bad
# 3104     11.1     bad
# 4190     12.0     bad
# 2133     11.9     bad

# %%
example = test[['quality']]
#example['quality'] = example.index.map(lambda x: float(x % 7 + 3))
example['quality'] = example.index.map(lambda x: 'good' if (x % 7 == 0) else 'bad')
example.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      quality
# wine
# 3123     bad
# 3903     bad
# 3104     bad
# 4190     bad
# 2133     bad

# %%
example.describe()
# Out:
#        quality
# count     1633
# unique       2
# top        bad
# freq      1406

# %%
train.to_csv('wine-train.csv')

test.drop(['quality'], axis=1).to_csv('wine-test.csv')
test[['quality']].to_csv('wine-solution.csv')

example.to_csv('wine-example.csv')

# %%
# !head wine-*.csv
# Out:
# ==> wine-example.csv <==
# wine,quality
# 3123,bad
# 3903,bad
# 3104,bad
# 4190,bad
# 2133,bad
# 2870,good
# 3876,bad
# 2937,bad
# 2195,bad
#
# ==> wine-solution.csv <==
# wine,quality
# 3123,bad
# 3903,bad
# 3104,bad
# 4190,bad
# 2133,bad
# 2870,good
# 3876,bad
# 2937,bad
# 2195,bad
#
# ==> wine-test.csv <==
# wine,fixed_acidity,volatile_acidity,citric_acid,residual_sugar,chlorides,free_sulfur_dioxide,total_sulfur_dioxide,density,ph,sulphates,alcohol
# 3123,5.5,0.18,0.22,5.5,0.037,10.0,86.0,0.99156,3.46,0.44,12.2
# 3903,5.8,0.27,0.26,3.5,0.071,26.0,69.0,0.98994,3.1,0.38,11.5
# 3104,7.6,0.21,0.49,2.5,0.047,20.0,130.0,0.99178,3.15,0.48,11.1
# 4190,7.0,0.22,0.3,1.4,0.04,14.0,63.0,0.98985,3.2,0.33,12.0
# 2133,8.3,0.24,0.27,2.1,0.03,22.0,162.0,0.9914,2.99,0.68,11.9
# 2870,6.7,0.48,0.32,1.4,0.021,22.0,121.0,0.9889,3.15,0.53,12.7
# 3876,6.1,0.22,0.28,16.55,0.059,54.0,135.0,0.99665,3.2,0.38,10.5
# 2937,7.7,0.25,0.3,7.8,0.038,67.0,196.0,0.99555,3.1,0.5,10.1
# 2195,6.8,0.25,0.18,1.4,0.056,13.0,137.0,0.9935,3.11,0.42,9.5
#
# ==> wine-train-scaled.csv <==
# wine,fixed_acidity,volatile_acidity,citric_acid,residual_sugar,chlorides,free_sulfur_dioxide,total_sulfur_dioxide,density,ph,sulphates,alcohol,quality
# 1942,0.4271844660194176,0.3163841807909604,0.3433734939759036,0.22085889570552147,0.14726027397260275,0.24175824175824173,0.8125,0.250433776749567,0.19090909090909092,0.48837209302325574,0.09999999999999987,0.33333333333333326
# 3847,0.24271844660194186,0.2711864406779661,0.1385542168674699,0.23926380368098157,0.15753424657534248,0.2490842490842491,0.549342105263158,0.22151532677848706,0.49090909090909074,0.372093023255814,0.18333333333333335,0.33333333333333326
# 3183,0.2524271844660194,0.1807909604519774,0.22891566265060243,0.006134969325153375,0.06164383561643837,0.21245421245421245,0.2664473684210526,0.04144977829188434,0.4727272727272731,0.16279069767441856,0.7166666666666666,0.5
# 2745,0.27184466019417486,0.4067796610169492,0.13253012048192772,0.0567484662576687,0.07876712328767124,0.12454212454212454,0.29605263157894735,0.0586080586080584,0.49090909090909074,0.3604651162790698,0.8,0.6666666666666665
