# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 3)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('wine-train.csv', index_col='wine')

# mostrar alguns exemplos de registros
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 2169            7.4              0.19         0.30            12.8      0.053
# 1382            6.6              0.56         0.16             3.1      0.045
# 3346            6.7              0.18         0.24            10.3      0.057
# 3308            6.4              0.35         0.28            12.6      0.039
# 3167            5.6              0.28         0.40             6.1      0.034
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 2169                 48.5                 229.0    0.999  3.14       0.49
# 1382                 28.0                  92.0    0.994  3.12       0.35
# 3346                 64.0                 185.0    0.995  3.12       0.50
# 3308                 19.0                 124.0    0.995  3.20       0.43
# 3167                 36.0                 118.0    0.991  3.21       0.43
#
#       alcohol quality
# wine
# 2169      9.1    good
# 1382      9.1     bad
# 3346     10.6     bad
# 3308     10.6     bad
# 3167     12.1    good

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (3265, 12)

# %% [markdown]
# ## Análise dos dados

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3265 entries, 2169 to 4278
# Data columns (total 12 columns):
# fixed_acidity           3265 non-null float64
# volatile_acidity        3265 non-null float64
# citric_acid             3265 non-null float64
# residual_sugar          3265 non-null float64
# chlorides               3265 non-null float64
# free_sulfur_dioxide     3265 non-null float64
# total_sulfur_dioxide    3265 non-null float64
# density                 3265 non-null float64
# ph                      3265 non-null float64
# sulphates               3265 non-null float64
# alcohol                 3265 non-null float64
# quality                 3265 non-null object
# dtypes: float64(11), object(1)
# memory usage: 318.8+ KB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
data.isna().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#                        count     mean     std     min      25%      50%  \
# fixed_acidity         3265.0    6.859   0.856   3.900    6.300    6.800
# volatile_acidity      3265.0    0.277   0.100   0.080    0.210    0.260
# citric_acid           3265.0    0.334   0.119   0.000    0.270    0.320
# residual_sugar        3265.0    6.432   4.997   0.600    1.700    5.300
# chlorides             3265.0    0.046   0.022   0.009    0.036    0.043
# free_sulfur_dioxide   3265.0   35.656  17.437   2.000   24.000   34.000
# total_sulfur_dioxide  3265.0  139.235  42.261  10.000  109.000  135.000
# density               3265.0    0.994   0.003   0.987    0.992    0.994
# ph                    3265.0    3.190   0.149   2.720    3.090    3.180
# sulphates             3265.0    0.492   0.114   0.220    0.410    0.480
# alcohol               3265.0   10.509   1.234   8.400    9.400   10.400
#
#                           75%      max
# fixed_acidity           7.300   14.200
# volatile_acidity        0.320    1.100
# citric_acid             0.380    1.660
# residual_sugar          9.850   31.600
# chlorides               0.050    0.346
# free_sulfur_dioxide    46.000  289.000
# total_sulfur_dioxide  168.000  440.000
# density                 0.996    1.010
# ph                      3.280    3.800
# sulphates               0.550    1.010
# alcohol                11.400   14.200

# %%
# quais as correlações entre as características numéricas?
data.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity                 1.000            -0.012        0.287
# volatile_acidity             -0.012             1.000       -0.146
# citric_acid                   0.287            -0.146        1.000
# residual_sugar                0.089             0.045        0.089
# chlorides                     0.018             0.082        0.076
# free_sulfur_dioxide          -0.036            -0.097        0.087
# total_sulfur_dioxide          0.112             0.089        0.104
# density                       0.281             0.008        0.133
# ph                           -0.429            -0.030       -0.162
# sulphates                    -0.026            -0.033        0.078
# alcohol                      -0.133             0.062       -0.045
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity                  0.089      0.018               -0.036
# volatile_acidity               0.045      0.082               -0.097
# citric_acid                    0.089      0.076                0.087
# residual_sugar                 1.000      0.109                0.290
# chlorides                      0.109      1.000                0.106
# free_sulfur_dioxide            0.290      0.106                1.000
# total_sulfur_dioxide           0.399      0.204                0.609
# density                        0.833      0.272                0.283
# ph                            -0.195     -0.094               -0.003
# sulphates                     -0.039      0.018                0.063
# alcohol                       -0.460     -0.363               -0.221
#
#                       total_sulfur_dioxide  density     ph  sulphates  alcohol
# fixed_acidity                        0.112    0.281 -0.429     -0.026   -0.133
# volatile_acidity                     0.089    0.008 -0.030     -0.033    0.062
# citric_acid                          0.104    0.133 -0.162      0.078   -0.045
# residual_sugar                       0.399    0.833 -0.195     -0.039   -0.460
# chlorides                            0.204    0.272 -0.094      0.018   -0.363
# free_sulfur_dioxide                  0.609    0.283 -0.003      0.063   -0.221
# total_sulfur_dioxide                 1.000    0.537 -0.009      0.134   -0.445
# density                              0.537    1.000 -0.108      0.063   -0.803
# ph                                  -0.009   -0.108  1.000      0.162    0.132
# sulphates                            0.134    0.063  0.162      1.000   -0.020
# alcohol                             -0.445   -0.803  0.132     -0.020    1.000

# %%
# show variable correlation which is more than 0.6 (positive or negative)
corr = data.corr()
corr[corr != 1][abs(corr) > 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
#                 residual_sugar  density  alcohol
# residual_sugar             NaN    0.833      NaN
# density                  0.833      NaN   -0.803
# alcohol                    NaN   -0.803      NaN

# %%
data.groupby('quality').mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# bad              6.892             0.281        0.336           6.750
# good             6.740             0.263        0.328           5.296
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density     ph  \
# quality
# bad          0.048               35.855               142.833    0.994  3.183
# good         0.038               34.947               126.379    0.992  3.217
#
#          sulphates  alcohol
# quality
# bad          0.489   10.257
# good         0.500   11.409

# %% [raw]
# numeric_feats = data.dtypes[data.dtypes != "object"].index
# numeric_feats

# %% [raw]
# from scipy.stats import skew
# skewed_feats = data[numeric_feats].apply(lambda x: skew(x.dropna())) # compute skewness
# skewed_feats = skewed_feats[skewed_feats > 0.75]
# skewed_feats = skewed_feats.index
# skewed_feats

# %% [raw]
# data.head(10).T

# %% [raw]
# data[skewed_feats] = np.log1p(data[skewed_feats])

# %% [raw]
# data.head(10).T

# %% [raw]
# data = pd.get_dummies(data)
# data = data.fillna(data.mean())

# %% [raw]
# # carregar arquivo de dados de treino (normalizados)
# data = pd.read_csv('wine-train-scaled.csv', index_col='wine')

# %% [raw]
# # https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
#
# Q1 = data.quantile(0.25)
# Q3 = data.quantile(0.75)
# IQR = Q3 - Q1
#
# print(IQR)
#
# '''
# print('')
# print(data.mean())
# print('')
# print(data.std())
# '''

# %% [raw]
# print(data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))

# %% [raw]
# # https://www.kdnuggets.com/2017/02/removing-outliers-standard-deviation-python.html
#
# #TODO: remover outliers para cada valor de "quality" (de 3 a 9)
#
# spread = 3
#
# removed_ids = ((data < (Q1 - spread * IQR)) | (data > (Q3 + spread * IQR))).index.values
# print('removed ids:', removed_ids)
#
# data_out = data[~((data < (Q1 - spread * IQR)) | (data > (Q3 + spread * IQR))).any(axis=1)]
# #data_out = data[~((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# print('before:', data.shape, '=> after:', data_out.shape,
#       ':: removed %d lines' % int(data.shape[0] - data_out.shape[0]))

# %% [raw]
# data_out.head(10).T

# %% [raw]
# data_out.to_csv('wine-train-without-outliers.csv')

# %% [raw]
# dtqu = data.drop(['quality'], axis=1).head()
# Q1 = dtqu.quantile(0.25)
# Q3 = dtqu.quantile(0.75)
# IQR = Q3 - Q1
# IQR

# %% [raw]
# (dtqu < (Q1 - spread * IQR)).head()

# %%
spread = 1.5

data['outlier'] = False

for quality in ['good', 'bad']:
#for quality in np.arange(3, 10):
#if (True):

    #quality = 5
    dtqu = data[data.quality == quality].drop(['quality'], axis=1)
    
    Q1 = dtqu.quantile(0.25)
    Q3 = dtqu.quantile(0.75)
    IQR = Q3 - Q1
    
    removed_ids = ~((dtqu < (Q1 - spread * IQR)) | (dtqu > (Q3 + spread * IQR))).any(axis=1)
    df_rids = pd.DataFrame(data=removed_ids, columns=['outlier'])
    
    data.update(df_rids)
    
    #print(quality, dtqu[dtqu.outlier == True].count())
    print(quality, data[data.outlier == False].shape[0])
# Out:
# good 2691
# bad 620

# %%
removed_ids.head()
# Out:
# wine
# 1382    False
# 3346     True
# 3308     True
# 1777     True
# 4721     True
# dtype: bool

# %%
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 2169            7.4              0.19         0.30            12.8      0.053
# 1382            6.6              0.56         0.16             3.1      0.045
# 3346            6.7              0.18         0.24            10.3      0.057
# 3308            6.4              0.35         0.28            12.6      0.039
# 3167            5.6              0.28         0.40             6.1      0.034
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 2169                 48.5                 229.0    0.999  3.14       0.49
# 1382                 28.0                  92.0    0.994  3.12       0.35
# 3346                 64.0                 185.0    0.995  3.12       0.50
# 3308                 19.0                 124.0    0.995  3.20       0.43
# 3167                 36.0                 118.0    0.991  3.21       0.43
#
#       alcohol quality outlier
# wine
# 2169      9.1    good   False
# 1382      9.1     bad   False
# 3346     10.6     bad    True
# 3308     10.6     bad    True
# 3167     12.1    good    True

# %%
data[['ph','outlier']].groupby('outlier').count()
# Out:
#            ph
# outlier
# False     620
# True     2645

# %%
data_without_outliers = data[data.outlier == False].drop(['outlier'], axis=1)
data_without_outliers.shape
# Out:
# (620, 12)

# %%
data_without_outliers.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 2169            7.4              0.19         0.30            12.8      0.053
# 1382            6.6              0.56         0.16             3.1      0.045
# 3755            7.8              0.19         0.32             7.4      0.015
# 1645            7.5              0.24         0.49             9.4      0.048
# 3379            7.6              0.36         0.49            11.3      0.046
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 2169                 48.5                 229.0    0.999  3.14       0.49
# 1382                 28.0                  92.0    0.994  3.12       0.35
# 3755                 47.0                 124.0    0.993  2.99       0.39
# 1645                 50.0                 149.0    0.996  3.17       0.59
# 3379                 87.0                 221.0    0.998  3.01       0.43
#
#       alcohol quality
# wine
# 2169      9.1    good
# 1382      9.1     bad
# 3755     11.0     bad
# 1645     10.5    good
# 3379      9.2     bad

# %%
data_without_outliers.to_csv('wine-train-without-outliers.csv')

# %%
data = data_without_outliers
data.quality = data.quality.map({'good': 1, 'bad': 0})
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 2169            7.4              0.19         0.30            12.8      0.053
# 1382            6.6              0.56         0.16             3.1      0.045
# 3755            7.8              0.19         0.32             7.4      0.015
# 1645            7.5              0.24         0.49             9.4      0.048
# 3379            7.6              0.36         0.49            11.3      0.046
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 2169                 48.5                 229.0    0.999  3.14       0.49
# 1382                 28.0                  92.0    0.994  3.12       0.35
# 3755                 47.0                 124.0    0.993  2.99       0.39
# 1645                 50.0                 149.0    0.996  3.17       0.59
# 3379                 87.0                 221.0    0.998  3.01       0.43
#
#       alcohol  quality
# wine
# 2169      9.1        1
# 1382      9.1        0
# 3755     11.0        0
# 1645     10.5        1
# 3379      9.2        0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(data))

data_filtered_scaled = pd.DataFrame(scaler.transform(data), columns=data.columns, index=data.index)
data_filtered_scaled.head()
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 2169          0.340              0.09        0.181           0.390      0.131
# 1382          0.262              0.46        0.096           0.075      0.107
# 3755          0.379              0.09        0.193           0.214      0.018
# 1645          0.350              0.14        0.295           0.279      0.116
# 3379          0.359              0.26        0.295           0.341      0.110
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density     ph  sulphates  \
# wine
# 2169                0.159                 0.509    0.489  0.389      0.316
# 1382                0.087                 0.191    0.288  0.370      0.132
# 3755                0.154                 0.265    0.235  0.250      0.184
# 1645                0.164                 0.323    0.384  0.417      0.447
# 3379                0.294                 0.491    0.480  0.269      0.237
#
#       alcohol  quality
# wine
# 2169    0.108      1.0
# 1382    0.108      0.0
# 3755    0.450      0.0
# 1645    0.360      1.0
# 3379    0.126      0.0

# %%
data_filtered_scaled.to_csv('wine-train-filtered-scaled.csv')
