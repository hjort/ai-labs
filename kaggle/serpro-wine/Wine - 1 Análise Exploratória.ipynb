# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 3)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('wine-train.csv', index_col='wine')

# mostrar alguns exemplos de registros
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0    0.993  3.30       0.59
# 3455                 29.0                  86.0    0.989  2.90       0.38
# 3322                 30.0                 105.0    0.990  3.48       0.52
# 4896                 20.0                 110.0    0.989  3.34       0.38
# 2123                 47.0                 154.0    0.997  3.05       0.38
#
#       alcohol quality
# wine
# 3472     10.5     bad
# 3455     12.2     bad
# 3322     12.5    good
# 4896     12.8    good
# 2123      9.0     bad

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (3265, 12)

# %% [markdown]
# ## Análise dos dados

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3265 entries, 3472 to 3696
# Data columns (total 12 columns):
# fixed_acidity           3265 non-null float64
# volatile_acidity        3265 non-null float64
# citric_acid             3265 non-null float64
# residual_sugar          3265 non-null float64
# chlorides               3265 non-null float64
# free_sulfur_dioxide     3265 non-null float64
# total_sulfur_dioxide    3265 non-null float64
# density                 3265 non-null float64
# ph                      3265 non-null float64
# sulphates               3265 non-null float64
# alcohol                 3265 non-null float64
# quality                 3265 non-null object
# dtypes: float64(11), object(1)
# memory usage: 318.8+ KB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
data.isna().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#                        count     mean     std     min      25%      50%  \
# fixed_acidity         3265.0    6.863   0.841   4.200    6.300    6.800
# volatile_acidity      3265.0    0.278   0.100   0.080    0.210    0.260
# citric_acid           3265.0    0.336   0.123   0.000    0.270    0.320
# residual_sugar        3265.0    6.529   5.136   0.600    1.800    5.400
# chlorides             3265.0    0.046   0.022   0.009    0.036    0.043
# free_sulfur_dioxide   3265.0   35.549  17.194   2.000   23.500   34.000
# total_sulfur_dioxide  3265.0  138.691  43.242  10.000  108.000  134.000
# density               3265.0    0.994   0.003   0.987    0.992    0.994
# ph                    3265.0    3.184   0.149   2.770    3.080    3.170
# sulphates             3265.0    0.490   0.113   0.230    0.410    0.470
# alcohol               3265.0   10.505   1.239   8.000    9.400   10.400
#
#                           75%      max
# fixed_acidity           7.400   14.200
# volatile_acidity        0.320    1.100
# citric_acid             0.390    1.660
# residual_sugar         10.200   65.800
# chlorides               0.050    0.346
# free_sulfur_dioxide    46.000  289.000
# total_sulfur_dioxide  168.000  440.000
# density                 0.996    1.039
# ph                      3.270    3.820
# sulphates               0.550    1.080
# alcohol                11.400   14.200

# %%
# quais as correlações entre as características numéricas?
data.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity                 1.000            -0.009        0.277
# volatile_acidity             -0.009             1.000       -0.139
# citric_acid                   0.277            -0.139        1.000
# residual_sugar                0.099             0.067        0.104
# chlorides                     0.014             0.071        0.113
# free_sulfur_dioxide          -0.036            -0.094        0.103
# total_sulfur_dioxide          0.111             0.088        0.139
# density                       0.265             0.036        0.158
# ph                           -0.421            -0.039       -0.152
# sulphates                    -0.013            -0.026        0.071
# alcohol                      -0.119             0.066       -0.081
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity                  0.099      0.014               -0.036
# volatile_acidity               0.067      0.071               -0.094
# citric_acid                    0.104      0.113                0.103
# residual_sugar                 1.000      0.090                0.330
# chlorides                      0.090      1.000                0.110
# free_sulfur_dioxide            0.330      0.110                1.000
# total_sulfur_dioxide           0.422      0.204                0.632
# density                        0.848      0.253                0.320
# ph                            -0.185     -0.094                0.008
# sulphates                     -0.015      0.012                0.053
# alcohol                       -0.465     -0.358               -0.262
#
#                       total_sulfur_dioxide  density     ph  sulphates  alcohol
# fixed_acidity                        0.111    0.265 -0.421     -0.013   -0.119
# volatile_acidity                     0.088    0.036 -0.039     -0.026    0.066
# citric_acid                          0.139    0.158 -0.152      0.071   -0.081
# residual_sugar                       0.422    0.848 -0.185     -0.015   -0.465
# chlorides                            0.204    0.253 -0.094      0.012   -0.358
# free_sulfur_dioxide                  0.632    0.320  0.008      0.053   -0.262
# total_sulfur_dioxide                 1.000    0.542  0.007      0.122   -0.457
# density                              0.542    1.000 -0.088      0.072   -0.777
# ph                                   0.007   -0.088  1.000      0.140    0.118
# sulphates                            0.122    0.072  0.140      1.000   -0.008
# alcohol                             -0.457   -0.777  0.118     -0.008    1.000

# %%
# show variable correlation which is more than 0.6 (positive or negative)
corr = data.corr()
corr[corr != 1][abs(corr) > 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
#                 residual_sugar  density  alcohol
# residual_sugar             NaN    0.848      NaN
# density                  0.848      NaN   -0.777
# alcohol                    NaN   -0.777      NaN

# %%
data.groupby('quality').mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# bad              6.899             0.282        0.338           6.858
# good             6.735             0.265        0.328           5.341
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density     ph  \
# quality
# bad          0.048               35.886               142.495    0.995  3.176
# good         0.038               34.337               125.004    0.992  3.212
#
#          sulphates  alcohol
# quality
# bad          0.488   10.248
# good         0.495   11.429

# %% [raw]
# numeric_feats = data.dtypes[data.dtypes != "object"].index
# numeric_feats

# %% [raw]
# from scipy.stats import skew
# skewed_feats = data[numeric_feats].apply(lambda x: skew(x.dropna())) # compute skewness
# skewed_feats = skewed_feats[skewed_feats > 0.75]
# skewed_feats = skewed_feats.index
# skewed_feats

# %% [raw]
# data.head(10).T

# %% [raw]
# data[skewed_feats] = np.log1p(data[skewed_feats])

# %% [raw]
# data.head(10).T

# %% [raw]
# data = pd.get_dummies(data)
# data = data.fillna(data.mean())

# %% [raw]
# # carregar arquivo de dados de treino (normalizados)
# data = pd.read_csv('wine-train-scaled.csv', index_col='wine')

# %% [raw]
# # https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
#
# Q1 = data.quantile(0.25)
# Q3 = data.quantile(0.75)
# IQR = Q3 - Q1
#
# print(IQR)
#
# '''
# print('')
# print(data.mean())
# print('')
# print(data.std())
# '''

# %% [raw]
# print(data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))

# %% [raw]
# # https://www.kdnuggets.com/2017/02/removing-outliers-standard-deviation-python.html
#
# #TODO: remover outliers para cada valor de "quality" (de 3 a 9)
#
# spread = 3
#
# removed_ids = ((data < (Q1 - spread * IQR)) | (data > (Q3 + spread * IQR))).index.values
# print('removed ids:', removed_ids)
#
# data_out = data[~((data < (Q1 - spread * IQR)) | (data > (Q3 + spread * IQR))).any(axis=1)]
# #data_out = data[~((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# print('before:', data.shape, '=> after:', data_out.shape,
#       ':: removed %d lines' % int(data.shape[0] - data_out.shape[0]))

# %% [raw]
# data_out.head(10).T

# %% [raw]
# data_out.to_csv('wine-train-without-outliers.csv')

# %% [raw]
# dtqu = data.drop(['quality'], axis=1).head()
# Q1 = dtqu.quantile(0.25)
# Q3 = dtqu.quantile(0.75)
# IQR = Q3 - Q1
# IQR

# %% [raw]
# (dtqu < (Q1 - spread * IQR)).head()

# %%
spread = 0.5

data['outlier'] = False

for quality in ['good', 'bad']:
#for quality in np.arange(3, 10):
#if (True):

    #quality = 5
    dtqu = data[data.quality == quality].drop(['quality'], axis=1)
    
    Q1 = dtqu.quantile(0.25)
    Q3 = dtqu.quantile(0.75)
    IQR = Q3 - Q1
    
    removed_ids = ~((dtqu < (Q1 - spread * IQR)) | (dtqu > (Q3 + spread * IQR))).any(axis=1)
    df_rids = pd.DataFrame(data=removed_ids, columns=['outlier'])
    
    data.update(df_rids)
    
    #print(quality, dtqu[dtqu.outlier == True].count())
    print(quality, data[data.outlier == False].shape[0])
# Out:
# good 3077
# bad 2582

# %%
removed_ids.head()
# Out:
# wine
# 3472    False
# 3455    False
# 2123    False
# 4678    False
# 3159    False
# dtype: bool

# %%
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0    0.993  3.30       0.59
# 3455                 29.0                  86.0    0.989  2.90       0.38
# 3322                 30.0                 105.0    0.990  3.48       0.52
# 4896                 20.0                 110.0    0.989  3.34       0.38
# 2123                 47.0                 154.0    0.997  3.05       0.38
#
#       alcohol quality outlier
# wine
# 3472     10.5     bad   False
# 3455     12.2     bad   False
# 3322     12.5    good   False
# 4896     12.8    good   False
# 2123      9.0     bad   False

# %%
data[['ph','outlier']].groupby('outlier').count()
# Out:
#            ph
# outlier
# False    2582
# True      683

# %%
data_without_outliers = data[data.outlier == False].drop(['outlier'], axis=1)
data_without_outliers.shape
# Out:
# (2582, 12)

# %%
data_without_outliers.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0    0.993  3.30       0.59
# 3455                 29.0                  86.0    0.989  2.90       0.38
# 3322                 30.0                 105.0    0.990  3.48       0.52
# 4896                 20.0                 110.0    0.989  3.34       0.38
# 2123                 47.0                 154.0    0.997  3.05       0.38
#
#       alcohol quality
# wine
# 3472     10.5     bad
# 3455     12.2     bad
# 3322     12.5    good
# 4896     12.8    good
# 2123      9.0     bad

# %%
data_without_outliers.to_csv('wine-train-without-outliers.csv')

# %%
data = data_without_outliers
data.quality = data.quality.map({'good': 1, 'bad': 0})
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472            6.7              0.16         0.36             2.0      0.045
# 3455            7.3              0.23         0.24             0.9      0.031
# 3322            5.7              0.26         0.30             1.8      0.039
# 4896            5.5              0.29         0.30             1.1      0.022
# 2123            6.8              0.25         0.27            10.7      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 3472                 24.0                 131.0    0.993  3.30       0.59
# 3455                 29.0                  86.0    0.989  2.90       0.38
# 3322                 30.0                 105.0    0.990  3.48       0.52
# 4896                 20.0                 110.0    0.989  3.34       0.38
# 2123                 47.0                 154.0    0.997  3.05       0.38
#
#       alcohol  quality
# wine
# 3472     10.5        0
# 3455     12.2        0
# 3322     12.5        1
# 4896     12.8        1
# 2123      9.0        0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(data))

data_filtered_scaled = pd.DataFrame(scaler.transform(data), columns=data.columns, index=data.index)
data_filtered_scaled.head()
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 3472           0.25             0.078        0.217           0.021      0.107
# 3455           0.31             0.147        0.145           0.005      0.065
# 3322           0.15             0.176        0.181           0.018      0.089
# 4896           0.13             0.206        0.181           0.008      0.039
# 2123           0.26             0.167        0.163           0.155      0.199
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density     ph  sulphates  \
# wine
# 3472                0.077                 0.281    0.110  0.505      0.424
# 3455                0.094                 0.177    0.041  0.124      0.176
# 3322                0.098                 0.221    0.054  0.676      0.341
# 4896                0.063                 0.233    0.030  0.543      0.176
# 2123                0.157                 0.335    0.185  0.267      0.176
#
#       alcohol  quality
# wine
# 3472    0.403      0.0
# 3455    0.677      0.0
# 3322    0.726      1.0
# 4896    0.774      1.0
# 2123    0.161      0.0

# %%
data_filtered_scaled.to_csv('wine-train-filtered-scaled.csv')
