# %%
# importar pacotes necessários
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# definir parâmetros extras
import warnings
warnings.filterwarnings("ignore")
sns.set(style="white", color_codes=True)

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('wine-train.csv', index_col='wine')

# mostrar alguns exemplos de registros
data.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# wine
# 1942            8.3              0.36         0.57            15.0      0.052
# 3847            6.4              0.32         0.23            16.2      0.055
# 3183            6.5              0.24         0.38             1.0      0.027
# 2745            6.7              0.44         0.22             4.3      0.032
# 2977            6.6              0.23         0.20            11.4      0.044
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# wine
# 1942                 35.0                 256.0  1.00010  2.93       0.64
# 3847                 36.0                 176.0  0.99860  3.26       0.54
# 3183                 31.0                  90.0  0.98926  3.24       0.36
# 2745                 19.0                  99.0  0.99015  3.26       0.53
# 2977                 45.0                 131.0  0.99604  2.96       0.51
#
#       alcohol  quality
# wine
# 1942      8.6      5.0
# 3847      9.1      5.0
# 3183     12.3      6.0
# 2745     12.8      7.0
# 2977      9.7      6.0

# %%
# quantos vinhos existem de cada qualidade?
data['quality'].value_counts()
# Out:
# 6.0    1469
# 5.0     975
# 7.0     595
# 8.0     121
# 4.0      93
# 3.0      10
# 9.0       2
# Name: quality, dtype: int64

# %%
# gerar gráfico de dispersão simples
data.plot(kind="scatter", x="alcohol", y="density")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# gerar gráfico de dispersão com histograma usando o pacote seaborn
sns.jointplot(x="alcohol", y="density", data=data, size=5, )

# %%
# gerar gráfico similar usando a espécie na cor
sns.FacetGrid(data, hue="quality", size=5) \
   .map(plt.scatter, "alcohol", "density") \
   .add_legend()

# %%
# gerar um gráfico do tipo boxplot sobre uma característica individual
sns.boxplot(x="quality", y="alcohol", data=data)

# %%
# gerar boxplot para cada uma das características por espécie
data.boxplot(by="quality", figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0xa6e46d2c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6e648ac>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6e7ae4c>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa6d7c5cc>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6d91cec>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6c8a46c>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa6ca2cec>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6c3f60c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6c3f6cc>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa6c5b06c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6c0b18c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa6c21aac>]],
#       dtype=object)

# %%
# gerar gráfico kde (densidade de kernel) sobre uma característica
sns.FacetGrid(data, hue="quality", size=6) \
   .map(sns.kdeplot, "alcohol") \
   .add_legend()

# %%
# gerar gráfico para analisar pares de características
sns.pairplot(data, hue="quality", size=3)

# %%
# gerar gráfico em pares com kde nas diagonais
sns.pairplot(data, hue="quality", size=3, diag_kind="kde")

# %%
# gerar mapa de calor com a correlação das características
sns.heatmap(data.corr(), annot=True, cmap='cubehelix_r')
