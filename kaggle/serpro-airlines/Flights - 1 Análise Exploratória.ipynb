# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('airlines-train.csv', index_col='FlightRecord')

# mostrar alguns exemplos de registros
data.head()
# Out:
#               FlightDate  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# FlightRecord
# 40108         2007-01-01   2021.0        2000   2212.0        2155
# 43494         2008-01-03    910.0         915    923.0         935
# 21603         1997-01-22   1422.0        1415   1614.0        1602
# 18691         1996-01-27   1125.0        1100   1337.0        1315
# 8022          1991-01-27   1703.0        1705   1931.0        1944
#
#              UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# FlightRecord
# 40108                   WN        149  N623SW               51.0
# 43494                   WN        453  N232WN               73.0
# 21603                   HP       2028  N311AW              112.0
# 18691                   WN       1488    N359               72.0
# 8022                    US        112     NaN              148.0
#
#               CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  \
# FlightRecord
# 40108                   55.0     41.0      17.0      21.0    STL  SDF
# 43494                   80.0     58.0     -12.0      -5.0    PHX  SNA
# 21603                  107.0     93.0      12.0       7.0    DEN  PHX
# 18691                   75.0     61.0      22.0      25.0    BUR  PHX
# 8022                   159.0      NaN     -13.0      -2.0    TPA  SYR
#
#               Distance  TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  \
# FlightRecord
# 40108            254.0     3.0      7.0          0              NaN         0
# 43494            338.0     4.0     11.0          0              NaN         0
# 21603            602.0     7.0     12.0          0              NaN         0
# 18691            369.0     5.0      6.0          0              NaN         0
# 8022            1104.0     NaN      NaN          0              NaN         0
#
#               CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# FlightRecord
# 40108                  2.0           0.0       0.0            0.0
# 43494                  NaN           NaN       NaN            NaN
# 21603                  NaN           NaN       NaN            NaN
# 18691                  NaN           NaN       NaN            NaN
# 8022                   NaN           NaN       NaN            NaN
#
#               LateAircraftDelay IsArrDelayed IsDepDelayed
# FlightRecord
# 40108                      15.0          YES          YES
# 43494                       NaN           NO           NO
# 21603                       NaN          YES          YES
# 18691                       NaN          YES          YES
# 8022                        NaN           NO           NO

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (35182, 28)

# %% [markdown]
# ## Análise dos dados

# %%
data.columns.values
# Out:
# array(['FlightDate', 'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime',
#        'UniqueCarrier', 'FlightNum', 'TailNum', 'ActualElapsedTime',
#        'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin',
#        'Dest', 'Distance', 'TaxiIn', 'TaxiOut', 'Cancelled',
#        'CancellationCode', 'Diverted', 'CarrierDelay', 'WeatherDelay',
#        'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'IsArrDelayed',
#        'IsDepDelayed'], dtype=object)

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35182 entries, 40108 to 2011
# Data columns (total 28 columns):
# FlightDate           35182 non-null object
# DepTime              34298 non-null float64
# CRSDepTime           35182 non-null int64
# ArrTime              34212 non-null float64
# CRSArrTime           35182 non-null int64
# UniqueCarrier        35182 non-null object
# FlightNum            35182 non-null int64
# TailNum              22346 non-null object
# ActualElapsedTime    34212 non-null float64
# CRSElapsedTime       35172 non-null float64
# AirTime              21841 non-null float64
# ArrDelay             34212 non-null float64
# DepDelay             34298 non-null float64
# Origin               35182 non-null object
# Dest                 35182 non-null object
# Distance             35155 non-null float64
# TaxiIn               22344 non-null float64
# TaxiOut              22346 non-null float64
# Cancelled            35182 non-null int64
# CancellationCode     189 non-null object
# Diverted             35182 non-null int64
# CarrierDelay         7136 non-null float64
# WeatherDelay         7136 non-null float64
# NASDelay             7136 non-null float64
# SecurityDelay        7136 non-null float64
# LateAircraftDelay    7136 non-null float64
# IsArrDelayed         35182 non-null object
# IsDepDelayed         35182 non-null object
# dtypes: float64(15), int64(5), object(8)
# memory usage: 6.7+ MB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# DepTime                884
# ArrTime                970
# TailNum              12836
# ActualElapsedTime      970
# CRSElapsedTime          10
# AirTime              13341
# ArrDelay               970
# DepDelay               884
# Distance                27
# TaxiIn               12838
# TaxiOut              12836
# CancellationCode     34993
# CarrierDelay         28046
# WeatherDelay         28046
# NASDelay             28046
# SecurityDelay        28046
# LateAircraftDelay    28046
# dtype: int64

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#                      count       mean       std   min     25%     50%  \
# DepTime            34298.0  1345.5412  465.3347   1.0   929.0  1330.0
# CRSDepTime         35182.0  1313.1056  476.2150   0.0   910.0  1320.0
# ArrTime            34212.0  1504.5727  483.9483   1.0  1118.0  1526.0
# CRSArrTime         35182.0  1485.2642  492.3544   0.0  1109.0  1516.0
# FlightNum          35182.0   819.5181  777.8129   1.0   204.0   557.0
# ActualElapsedTime  34212.0   124.8756   73.9543  16.0    71.0   101.0
# CRSElapsedTime     35172.0   125.0090   73.2944  17.0    71.0   102.0
# AirTime            21841.0   114.3403   69.5007  14.0    61.0    91.0
# ArrDelay           34212.0     9.2457   29.3740 -63.0    -6.0     2.0
# DepDelay           34298.0     9.8819   25.9745 -16.0    -2.0     1.0
# Distance           35155.0   730.3510  577.6880  11.0   326.0   543.0
# TaxiIn             22344.0     5.3737    4.1303   0.0     3.0     5.0
# TaxiOut            22346.0    14.1719    9.9309   0.0     9.0    12.0
# Cancelled          35182.0     0.0251    0.1565   0.0     0.0     0.0
# Diverted           35182.0     0.0024    0.0494   0.0     0.0     0.0
# CarrierDelay        7136.0     4.0095   16.3437   0.0     0.0     0.0
# WeatherDelay        7136.0     0.3283    4.8689   0.0     0.0     0.0
# NASDelay            7136.0     4.7812   18.4578   0.0     0.0     0.0
# SecurityDelay       7136.0     0.0167    0.3992   0.0     0.0     0.0
# LateAircraftDelay   7136.0     7.4609   22.8391   0.0     0.0     0.0
#
#                        75%     max
# DepTime            1735.00  2400.0
# CRSDepTime         1720.00  2359.0
# ArrTime            1917.00  2400.0
# CRSArrTime         1902.00  2359.0
# FlightNum          1242.75  3948.0
# ActualElapsedTime   151.00   475.0
# CRSElapsedTime      151.00   437.0
# AirTime             140.00   402.0
# ArrDelay             15.00   475.0
# DepDelay             10.00   473.0
# Distance            920.00  3365.0
# TaxiIn                6.00   128.0
# TaxiOut              16.00   254.0
# Cancelled             0.00     1.0
# Diverted              0.00     1.0
# CarrierDelay          0.00   369.0
# WeatherDelay          0.00   201.0
# NASDelay              0.00   323.0
# SecurityDelay         0.00    13.0
# LateAircraftDelay     0.00   343.0

# %%
# sumário das características textuais
data.describe(include=['O']).T
# Out:
#                   count unique         top   freq
# FlightDate        35182    594  2008-01-03   1606
# UniqueCarrier     35182     10          US  14967
# TailNum           22346   3383      UNKNOW    144
# Origin            35182    131         DEN   2845
# Dest              35182    134         PHX   7451
# CancellationCode    189      3           B     80
# IsArrDelayed      35182      2         YES  19598
# IsDepDelayed      35182      2         YES  18507

# %%
# quais as correlações entre as características numéricas?
corr = pd.get_dummies(data, columns=['survived', 'sex', 'embarked']).corr()
corr
# Out:
#               pclass     age   sibsp   parch    fare  survived_no  \
# pclass        1.0000 -0.4396  0.0695  0.0156 -0.5721       0.2944
# age          -0.4396  1.0000 -0.2487 -0.1694  0.1838       0.0483
# sibsp         0.0695 -0.2487  1.0000  0.3849  0.1865       0.0259
# parch         0.0156 -0.1694  0.3849  1.0000  0.2559      -0.0784
# fare         -0.5721  0.1838  0.1865  0.2559  1.0000      -0.2405
# survived_no   0.2944  0.0483  0.0259 -0.0784 -0.2405       1.0000
# survived_yes -0.2944 -0.0483 -0.0259  0.0784  0.2405      -1.0000
# sex_female   -0.0897 -0.0871  0.1015  0.2209  0.1734      -0.5134
# sex_male      0.0897  0.0871 -0.1015 -0.2209 -0.1734       0.5134
# embarked_C   -0.2335  0.1214 -0.0467 -0.0169  0.2415      -0.1403
# embarked_Q    0.2260 -0.0035 -0.0342 -0.0926 -0.1323      -0.0007
# embarked_S    0.0677 -0.1190  0.0651  0.0762 -0.1320       0.1297
#
#               survived_yes  sex_female  sex_male  embarked_C  embarked_Q  \
# pclass             -0.2944     -0.0897    0.0897     -0.2335      0.2260
# age                -0.0483     -0.0871    0.0871      0.1214     -0.0035
# sibsp              -0.0259      0.1015   -0.1015     -0.0467     -0.0342
# parch               0.0784      0.2209   -0.2209     -0.0169     -0.0926
# fare                0.2405      0.1734   -0.1734      0.2415     -0.1323
# survived_no        -1.0000     -0.5134    0.5134     -0.1403     -0.0007
# survived_yes        1.0000      0.5134   -0.5134      0.1403      0.0007
# sex_female          0.5134      1.0000   -1.0000      0.0437      0.0859
# sex_male           -0.5134     -1.0000    1.0000     -0.0437     -0.0859
# embarked_C          0.1403      0.0437   -0.0437      1.0000     -0.1586
# embarked_Q          0.0007      0.0859   -0.0859     -0.1586      1.0000
# embarked_S         -0.1297     -0.0999    0.0999     -0.7711     -0.4978
#
#               embarked_S
# pclass            0.0677
# age              -0.1190
# sibsp             0.0651
# parch             0.0762
# fare             -0.1320
# survived_no       0.1297
# survived_yes     -0.1297
# sex_female       -0.0999
# sex_male          0.0999
# embarked_C       -0.7711
# embarked_Q       -0.4978
# embarked_S        1.0000

# %%
# quais as correlações mais expressivas entre as variáveis?
corr[corr != 1][abs(corr) > 0.05].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
#               pclass     age   sibsp   parch    fare  survived_no  \
# pclass           NaN -0.4396  0.0695     NaN -0.5721       0.2944
# age          -0.4396     NaN -0.2487 -0.1694  0.1838          NaN
# sibsp         0.0695 -0.2487     NaN  0.3849  0.1865          NaN
# parch            NaN -0.1694  0.3849     NaN  0.2559      -0.0784
# fare         -0.5721  0.1838  0.1865  0.2559     NaN      -0.2405
# survived_no   0.2944     NaN     NaN -0.0784 -0.2405          NaN
# survived_yes -0.2944     NaN     NaN  0.0784  0.2405      -1.0000
# sex_female   -0.0897 -0.0871  0.1015  0.2209  0.1734      -0.5134
# sex_male      0.0897  0.0871 -0.1015 -0.2209 -0.1734       0.5134
# embarked_C   -0.2335  0.1214     NaN     NaN  0.2415      -0.1403
# embarked_Q    0.2260     NaN     NaN -0.0926 -0.1323          NaN
# embarked_S    0.0677 -0.1190  0.0651  0.0762 -0.1320       0.1297
#
#               survived_yes  sex_female  sex_male  embarked_C  embarked_Q  \
# pclass             -0.2944     -0.0897    0.0897     -0.2335      0.2260
# age                    NaN     -0.0871    0.0871      0.1214         NaN
# sibsp                  NaN      0.1015   -0.1015         NaN         NaN
# parch               0.0784      0.2209   -0.2209         NaN     -0.0926
# fare                0.2405      0.1734   -0.1734      0.2415     -0.1323
# survived_no        -1.0000     -0.5134    0.5134     -0.1403         NaN
# survived_yes           NaN      0.5134   -0.5134      0.1403         NaN
# sex_female          0.5134         NaN   -1.0000         NaN      0.0859
# sex_male           -0.5134     -1.0000       NaN         NaN     -0.0859
# embarked_C          0.1403         NaN       NaN         NaN     -0.1586
# embarked_Q             NaN      0.0859   -0.0859     -0.1586         NaN
# embarked_S         -0.1297     -0.0999    0.0999     -0.7711     -0.4978
#
#               embarked_S
# pclass            0.0677
# age              -0.1190
# sibsp             0.0651
# parch             0.0762
# fare             -0.1320
# survived_no       0.1297
# survived_yes     -0.1297
# sex_female       -0.0999
# sex_male          0.0999
# embarked_C       -0.7711
# embarked_Q       -0.4978
# embarked_S           NaN

# %%
data.groupby('IsDepDelayed').mean().T
# Out:
# IsDepDelayed              NO        YES
# DepTime            1274.7797  1412.4962
# CRSDepTime         1268.5779  1353.2255
# ArrTime            1445.8084  1560.2985
# CRSArrTime         1435.9580  1529.6896
# FlightNum           837.1076   803.6697
# ActualElapsedTime   119.8412   129.6497
# CRSElapsedTime      120.6237   128.9623
# AirTime             109.8696   119.2413
# ArrDelay             -3.0240    20.8809
# DepDelay             -2.2748    21.3847
# Distance            695.8917   761.4055
# TaxiIn                5.6854     5.0470
# TaxiOut              14.1395    14.2059
# Cancelled             0.0000     0.0478
# Diverted              0.0014     0.0034
# CarrierDelay          0.0000     7.4414
# WeatherDelay          0.0000     0.6094
# NASDelay              1.9720     7.1857
# SecurityDelay         0.0000     0.0309
# LateAircraftDelay     0.0000    13.8468

# %%
data2 = data[['pclass', 'survived', 'sex', 'sibsp', 'parch']]
data2.survived = data2.survived.map({'yes': 1, 'no': 0})
data2.head()
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#         pclass  survived     sex  sibsp  parch
# person
# 416          2         0    male      0      0
# 194          1         0    male      0      0
# 600          3         0    male      0      0
# 1112         3         0  female      1      1
# 878          3         0  female      1      0

# %%
# existe correlação entre sobrevivência e classe social?
data2[['pclass', 'survived']].groupby(['pclass'], as_index=False).mean().\
  sort_values(by='survived', ascending=False)
# Out:
#    pclass  survived
# 0       1    0.5946
# 1       2    0.3934
# 2       3    0.2527

# %%
data['UniqueCarrier'].value_counts()
# Out:
# US    14967
# UA     7546
# WN     4951
# HP     2770
# PS     2572
# DL      740
# PI      641
# AA      574
# TW      254
# CO      167
# Name: UniqueCarrier, dtype: int64

# %%
# existe correlação da sobrevivência com o deque?
corr = pd.get_dummies(data, columns=['IsDepDelayed', 'UniqueCarrier']).corr()
corr
# Out:
#                    DepTime  CRSDepTime  ArrTime  CRSArrTime  FlightNum  \
# DepTime             1.0000      0.9171   0.7945      0.7983     0.0133
# CRSDepTime          0.9171      1.0000   0.7390      0.8832     0.0092
# ArrTime             0.7945      0.7390   1.0000      0.8395    -0.0049
# CRSArrTime          0.7983      0.8832   0.8395      1.0000    -0.0033
# FlightNum           0.0133      0.0092  -0.0049     -0.0033     1.0000
# ActualElapsedTime  -0.0469     -0.0655   0.0727      0.0548    -0.0552
# CRSElapsedTime     -0.0427     -0.0623   0.0730      0.0599    -0.0485
# AirTime            -0.0448     -0.0560   0.0479      0.0318    -0.0495
# ArrDelay            0.1821      0.1000   0.0915      0.1020     0.0078
# DepDelay            0.2183      0.1218   0.1038      0.1248     0.0180
# Distance           -0.0404     -0.0518   0.0788      0.0733    -0.0563
# TaxiIn             -0.0101      0.0067   0.0335      0.0320    -0.0321
# TaxiOut             0.0078     -0.0353   0.0126     -0.0167    -0.1076
# Cancelled              NaN     -0.0022      NaN     -0.0071    -0.0064
# Diverted           -0.0189     -0.0223      NaN     -0.0216    -0.0034
# CarrierDelay        0.1000      0.0435   0.0065      0.0413     0.0596
# WeatherDelay        0.0221      0.0063  -0.0027      0.0100    -0.0049
# NASDelay            0.0695      0.0352   0.1045      0.0540    -0.0521
# SecurityDelay      -0.0136     -0.0155  -0.0053     -0.0104     0.0265
# LateAircraftDelay   0.2859      0.2055   0.0599      0.1929     0.0803
# IsDepDelayed_NO    -0.1479     -0.0888  -0.1182     -0.0951     0.0215
# IsDepDelayed_YES    0.1479      0.0888   0.1182      0.0951    -0.0215
# UniqueCarrier_AA    0.0503     -0.2663   0.0408     -0.2872     0.0160
# UniqueCarrier_CO   -0.0264     -0.0227  -0.0144     -0.0113     0.0566
# UniqueCarrier_DL    0.0489      0.0488   0.0533      0.0633    -0.0155
# UniqueCarrier_HP   -0.0236     -0.0095   0.0043      0.0110     0.3951
# UniqueCarrier_PI    0.0454      0.0508   0.0265      0.0273     0.0232
# UniqueCarrier_PS   -0.0143      0.0012  -0.0591     -0.0534     0.2384
# UniqueCarrier_TW    0.0242      0.0257   0.0026      0.0135    -0.0486
# UniqueCarrier_UA    0.0231      0.0444   0.0359      0.0724    -0.0455
# UniqueCarrier_US   -0.0466     -0.0057  -0.0262     -0.0035    -0.4509
# UniqueCarrier_WN    0.0115      0.0177  -0.0087      0.0180     0.2026
#
#                    ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  \
# DepTime                      -0.0469         -0.0427  -0.0448    0.1821
# CRSDepTime                   -0.0655         -0.0623  -0.0560    0.1000
# ArrTime                       0.0727          0.0730   0.0479    0.0915
# CRSArrTime                    0.0548          0.0599   0.0318    0.1020
# FlightNum                    -0.0552         -0.0485  -0.0495    0.0078
# ActualElapsedTime             1.0000          0.9842   0.9890    0.1286
# CRSElapsedTime                0.9842          1.0000   0.9880    0.0441
# AirTime                       0.9890          0.9880   1.0000    0.0828
# ArrDelay                      0.1286          0.0441   0.0828    1.0000
# DepDelay                      0.0823          0.0758   0.0601    0.8947
# Distance                      0.9725          0.9851   0.9785    0.0460
# TaxiIn                        0.1430          0.0969   0.0827    0.1107
# TaxiOut                       0.2705          0.1536   0.1371    0.3507
# Cancelled                        NaN         -0.0409  -0.0232       NaN
# Diverted                         NaN          0.0119      NaN       NaN
# CarrierDelay                  0.0248          0.0204   0.0228    0.5094
# WeatherDelay                  0.0357          0.0138   0.0173    0.1881
# NASDelay                      0.1931          0.0514   0.0896    0.5264
# SecurityDelay                -0.0010         -0.0028   0.0018    0.0124
# LateAircraftDelay            -0.0384         -0.0333  -0.0390    0.6824
# IsDepDelayed_NO              -0.0663         -0.0568  -0.0674   -0.4068
# IsDepDelayed_YES              0.0663          0.0568   0.0674    0.4068
# UniqueCarrier_AA              0.0774          0.0801   0.0734    0.0131
# UniqueCarrier_CO              0.1381          0.1397   0.1644   -0.0075
# UniqueCarrier_DL              0.2380          0.2370   0.2840    0.0400
# UniqueCarrier_HP              0.1595          0.1555   0.1685    0.0032
# UniqueCarrier_PI             -0.1149         -0.1218      NaN    0.0044
# UniqueCarrier_PS             -0.2047         -0.2175      NaN    0.0051
# UniqueCarrier_TW              0.0049          0.0043  -0.0176    0.0375
# UniqueCarrier_UA              0.1490          0.1507   0.0134    0.0124
# UniqueCarrier_US             -0.1193         -0.1258  -0.1577   -0.0516
# UniqueCarrier_WN             -0.0884         -0.0651  -0.1522    0.0216
#
#                    DepDelay  Distance  TaxiIn  TaxiOut  Cancelled  Diverted  \
# DepTime              0.2183   -0.0404 -0.0101   0.0078        NaN   -0.0189
# CRSDepTime           0.1218   -0.0518  0.0067  -0.0353    -0.0022   -0.0223
# ArrTime              0.1038    0.0788  0.0335   0.0126        NaN       NaN
# CRSArrTime           0.1248    0.0733  0.0320  -0.0167    -0.0071   -0.0216
# FlightNum            0.0180   -0.0563 -0.0321  -0.1076    -0.0064   -0.0034
# ActualElapsedTime    0.0823    0.9725  0.1430   0.2705        NaN       NaN
# CRSElapsedTime       0.0758    0.9851  0.0969   0.1536    -0.0409    0.0119
# AirTime              0.0601    0.9785  0.0827   0.1371    -0.0232       NaN
# ArrDelay             0.8947    0.0460  0.1107   0.3507        NaN       NaN
# DepDelay             1.0000    0.0687  0.0060   0.1027        NaN    0.0509
# Distance             0.0687    1.0000  0.0914   0.1273    -0.0460    0.0093
# TaxiIn               0.0060    0.0914  1.0000   0.0783    -0.1793   -0.0610
# TaxiOut              0.1027    0.1273  0.0783   1.0000    -0.1972    0.0211
# Cancelled               NaN   -0.0460 -0.1793  -0.1972     1.0000   -0.0079
# Diverted             0.0509    0.0093 -0.0610   0.0211    -0.0079    1.0000
# CarrierDelay         0.5460    0.0190 -0.0135   0.0335    -0.0372   -0.0109
# WeatherDelay         0.1647    0.0112  0.0232   0.1029    -0.0102   -0.0030
# NASDelay             0.3148    0.0421  0.2069   0.5412    -0.0392   -0.0115
# SecurityDelay        0.0099    0.0013  0.0064  -0.0161    -0.0063   -0.0019
# LateAircraftDelay    0.7514   -0.0355 -0.0259   0.0174    -0.0495   -0.0145
# IsDepDelayed_NO     -0.4553   -0.0566  0.0773  -0.0033    -0.1524   -0.0205
# IsDepDelayed_YES     0.4553    0.0566 -0.0773   0.0033     0.1524    0.0205
# UniqueCarrier_AA     0.0215    0.0640 -0.0365   0.0723    -0.0078   -0.0018
# UniqueCarrier_CO    -0.0048    0.1204  0.0158   0.0515    -0.0111    0.0050
# UniqueCarrier_DL     0.0384    0.2204 -0.0240   0.0797    -0.0134   -0.0032
# UniqueCarrier_HP    -0.0224    0.1350  0.0426  -0.0363     0.0124   -0.0081
# UniqueCarrier_PI    -0.0027   -0.1147     NaN      NaN     0.0406    0.0148
# UniqueCarrier_PS    -0.0364   -0.1851     NaN      NaN    -0.0276   -0.0028
# UniqueCarrier_TW     0.0387    0.0122 -0.0140   0.0671     0.0271   -0.0042
# UniqueCarrier_UA     0.0097    0.1638  0.0306   0.1320    -0.0211   -0.0132
# UniqueCarrier_US    -0.0603   -0.1382  0.0814   0.0288     0.0415    0.0179
# UniqueCarrier_WN     0.0874   -0.0599 -0.1329  -0.2338    -0.0347   -0.0051
#
#                    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# DepTime                  0.1000        0.0221    0.0695        -0.0136
# CRSDepTime               0.0435        0.0063    0.0352        -0.0155
# ArrTime                  0.0065       -0.0027    0.1045        -0.0053
# CRSArrTime               0.0413        0.0100    0.0540        -0.0104
# FlightNum                0.0596       -0.0049   -0.0521         0.0265
# ActualElapsedTime        0.0248        0.0357    0.1931        -0.0010
# CRSElapsedTime           0.0204        0.0138    0.0514        -0.0028
# AirTime                  0.0228        0.0173    0.0896         0.0018
# ArrDelay                 0.5094        0.1881    0.5264         0.0124
# DepDelay                 0.5460        0.1647    0.3148         0.0099
# Distance                 0.0190        0.0112    0.0421         0.0013
# TaxiIn                  -0.0135        0.0232    0.2069         0.0064
# TaxiOut                  0.0335        0.1029    0.5412        -0.0161
# Cancelled               -0.0372       -0.0102   -0.0392        -0.0063
# Diverted                -0.0109       -0.0030   -0.0115        -0.0019
# CarrierDelay             1.0000       -0.0144    0.0076        -0.0102
# WeatherDelay            -0.0144        1.0000    0.0602        -0.0028
# NASDelay                 0.0076        0.0602    1.0000        -0.0012
# SecurityDelay           -0.0102       -0.0028   -0.0012         1.0000
# LateAircraftDelay        0.0931        0.0511    0.0114         0.0068
# IsDepDelayed_NO         -0.2270       -0.0624   -0.1408        -0.0387
# IsDepDelayed_YES         0.2270        0.0624    0.1408         0.0387
# UniqueCarrier_AA            NaN           NaN       NaN            NaN
# UniqueCarrier_CO            NaN           NaN       NaN            NaN
# UniqueCarrier_DL            NaN           NaN       NaN            NaN
# UniqueCarrier_HP            NaN           NaN       NaN            NaN
# UniqueCarrier_PI            NaN           NaN       NaN            NaN
# UniqueCarrier_PS            NaN           NaN       NaN            NaN
# UniqueCarrier_TW            NaN           NaN       NaN            NaN
# UniqueCarrier_UA        -0.0177        0.0171    0.1011        -0.0375
# UniqueCarrier_US        -0.0860        0.0111    0.0136        -0.0224
# UniqueCarrier_WN         0.0947       -0.0278   -0.1188         0.0594
#
#                    LateAircraftDelay  IsDepDelayed_NO  IsDepDelayed_YES  \
# DepTime                       0.2859          -0.1479            0.1479
# CRSDepTime                    0.2055          -0.0888            0.0888
# ArrTime                       0.0599          -0.1182            0.1182
# CRSArrTime                    0.1929          -0.0951            0.0951
# FlightNum                     0.0803           0.0215           -0.0215
# ActualElapsedTime            -0.0384          -0.0663            0.0663
# CRSElapsedTime               -0.0333          -0.0568            0.0568
# AirTime                      -0.0390          -0.0674            0.0674
# ArrDelay                      0.6824          -0.4068            0.4068
# DepDelay                      0.7514          -0.4553            0.4553
# Distance                     -0.0355          -0.0566            0.0566
# TaxiIn                       -0.0259           0.0773           -0.0773
# TaxiOut                       0.0174          -0.0033            0.0033
# Cancelled                    -0.0495          -0.1524            0.1524
# Diverted                     -0.0145          -0.0205            0.0205
# CarrierDelay                  0.0931          -0.2270            0.2270
# WeatherDelay                  0.0511          -0.0624            0.0624
# NASDelay                      0.0114          -0.1408            0.1408
# SecurityDelay                 0.0068          -0.0387            0.0387
# LateAircraftDelay             1.0000          -0.3022            0.3022
# IsDepDelayed_NO              -0.3022           1.0000           -1.0000
# IsDepDelayed_YES              0.3022          -1.0000            1.0000
# UniqueCarrier_AA                 NaN          -0.0207            0.0207
# UniqueCarrier_CO                 NaN           0.0073           -0.0073
# UniqueCarrier_DL                 NaN          -0.0531            0.0531
# UniqueCarrier_HP                 NaN           0.0953           -0.0953
# UniqueCarrier_PI                 NaN          -0.0203            0.0203
# UniqueCarrier_PS                 NaN          -0.0072            0.0072
# UniqueCarrier_TW                 NaN          -0.0144            0.0144
# UniqueCarrier_UA             -0.0465           0.0860           -0.0860
# UniqueCarrier_US             -0.0844          -0.0229            0.0229
# UniqueCarrier_WN              0.1238          -0.0982            0.0982
#
#                    UniqueCarrier_AA  UniqueCarrier_CO  UniqueCarrier_DL  \
# DepTime                      0.0503           -0.0264            0.0489
# CRSDepTime                  -0.2663           -0.0227            0.0488
# ArrTime                      0.0408           -0.0144            0.0533
# CRSArrTime                  -0.2872           -0.0113            0.0633
# FlightNum                    0.0160            0.0566           -0.0155
# ActualElapsedTime            0.0774            0.1381            0.2380
# CRSElapsedTime               0.0801            0.1397            0.2370
# AirTime                      0.0734            0.1644            0.2840
# ArrDelay                     0.0131           -0.0075            0.0400
# DepDelay                     0.0215           -0.0048            0.0384
# Distance                     0.0640            0.1204            0.2204
# TaxiIn                      -0.0365            0.0158           -0.0240
# TaxiOut                      0.0723            0.0515            0.0797
# Cancelled                   -0.0078           -0.0111           -0.0134
# Diverted                    -0.0018            0.0050           -0.0032
# CarrierDelay                    NaN               NaN               NaN
# WeatherDelay                    NaN               NaN               NaN
# NASDelay                        NaN               NaN               NaN
# SecurityDelay                   NaN               NaN               NaN
# LateAircraftDelay               NaN               NaN               NaN
# IsDepDelayed_NO             -0.0207            0.0073           -0.0531
# IsDepDelayed_YES             0.0207           -0.0073            0.0531
# UniqueCarrier_AA             1.0000           -0.0089           -0.0189
# UniqueCarrier_CO            -0.0089            1.0000           -0.0101
# UniqueCarrier_DL            -0.0189           -0.0101            1.0000
# UniqueCarrier_HP            -0.0376           -0.0202           -0.0429
# UniqueCarrier_PI            -0.0175           -0.0094           -0.0200
# UniqueCarrier_PS            -0.0362           -0.0194           -0.0412
# UniqueCarrier_TW            -0.0110           -0.0059           -0.0125
# UniqueCarrier_UA            -0.0673           -0.0361           -0.0766
# UniqueCarrier_US            -0.1108           -0.0594           -0.1261
# UniqueCarrier_WN            -0.0521           -0.0279           -0.0593
#
#                    UniqueCarrier_HP  UniqueCarrier_PI  UniqueCarrier_PS  \
# DepTime                     -0.0236            0.0454           -0.0143
# CRSDepTime                  -0.0095            0.0508            0.0012
# ArrTime                      0.0043            0.0265           -0.0591
# CRSArrTime                   0.0110            0.0273           -0.0534
# FlightNum                    0.3951            0.0232            0.2384
# ActualElapsedTime            0.1595           -0.1149           -0.2047
# CRSElapsedTime               0.1555           -0.1218           -0.2175
# AirTime                      0.1685               NaN               NaN
# ArrDelay                     0.0032            0.0044            0.0051
# DepDelay                    -0.0224           -0.0027           -0.0364
# Distance                     0.1350           -0.1147           -0.1851
# TaxiIn                       0.0426               NaN               NaN
# TaxiOut                     -0.0363               NaN               NaN
# Cancelled                    0.0124            0.0406           -0.0276
# Diverted                    -0.0081            0.0148           -0.0028
# CarrierDelay                    NaN               NaN               NaN
# WeatherDelay                    NaN               NaN               NaN
# NASDelay                        NaN               NaN               NaN
# SecurityDelay                   NaN               NaN               NaN
# LateAircraftDelay               NaN               NaN               NaN
# IsDepDelayed_NO              0.0953           -0.0203           -0.0072
# IsDepDelayed_YES            -0.0953            0.0203            0.0072
# UniqueCarrier_AA            -0.0376           -0.0175           -0.0362
# UniqueCarrier_CO            -0.0202           -0.0094           -0.0194
# UniqueCarrier_DL            -0.0429           -0.0200           -0.0412
# UniqueCarrier_HP             1.0000           -0.0398           -0.0821
# UniqueCarrier_PI            -0.0398            1.0000           -0.0383
# UniqueCarrier_PS            -0.0821           -0.0383            1.0000
# UniqueCarrier_TW            -0.0249           -0.0116           -0.0239
# UniqueCarrier_UA            -0.1528           -0.0712           -0.1468
# UniqueCarrier_US            -0.2515           -0.1172           -0.2417
# UniqueCarrier_WN            -0.1183           -0.0551           -0.1137
#
#                    UniqueCarrier_TW  UniqueCarrier_UA  UniqueCarrier_US  \
# DepTime                      0.0242            0.0231           -0.0466
# CRSDepTime                   0.0257            0.0444           -0.0057
# ArrTime                      0.0026            0.0359           -0.0262
# CRSArrTime                   0.0135            0.0724           -0.0035
# FlightNum                   -0.0486           -0.0455           -0.4509
# ActualElapsedTime            0.0049            0.1490           -0.1193
# CRSElapsedTime               0.0043            0.1507           -0.1258
# AirTime                     -0.0176            0.0134           -0.1577
# ArrDelay                     0.0375            0.0124           -0.0516
# DepDelay                     0.0387            0.0097           -0.0603
# Distance                     0.0122            0.1638           -0.1382
# TaxiIn                      -0.0140            0.0306            0.0814
# TaxiOut                      0.0671            0.1320            0.0288
# Cancelled                    0.0271           -0.0211            0.0415
# Diverted                    -0.0042           -0.0132            0.0179
# CarrierDelay                    NaN           -0.0177           -0.0860
# WeatherDelay                    NaN            0.0171            0.0111
# NASDelay                        NaN            0.1011            0.0136
# SecurityDelay                   NaN           -0.0375           -0.0224
# LateAircraftDelay               NaN           -0.0465           -0.0844
# IsDepDelayed_NO             -0.0144            0.0860           -0.0229
# IsDepDelayed_YES             0.0144           -0.0860            0.0229
# UniqueCarrier_AA            -0.0110           -0.0673           -0.1108
# UniqueCarrier_CO            -0.0059           -0.0361           -0.0594
# UniqueCarrier_DL            -0.0125           -0.0766           -0.1261
# UniqueCarrier_HP            -0.0249           -0.1528           -0.2515
# UniqueCarrier_PI            -0.0116           -0.0712           -0.1172
# UniqueCarrier_PS            -0.0239           -0.1468           -0.2417
# UniqueCarrier_TW             1.0000           -0.0446           -0.0734
# UniqueCarrier_UA            -0.0446            1.0000           -0.4496
# UniqueCarrier_US            -0.0734           -0.4496            1.0000
# UniqueCarrier_WN            -0.0345           -0.2115           -0.3482
#
#                    UniqueCarrier_WN
# DepTime                      0.0115
# CRSDepTime                   0.0177
# ArrTime                     -0.0087
# CRSArrTime                   0.0180
# FlightNum                    0.2026
# ActualElapsedTime           -0.0884
# CRSElapsedTime              -0.0651
# AirTime                     -0.1522
# ArrDelay                     0.0216
# DepDelay                     0.0874
# Distance                    -0.0599
# TaxiIn                      -0.1329
# TaxiOut                     -0.2338
# Cancelled                   -0.0347
# Diverted                    -0.0051
# CarrierDelay                 0.0947
# WeatherDelay                -0.0278
# NASDelay                    -0.1188
# SecurityDelay                0.0594
# LateAircraftDelay            0.1238
# IsDepDelayed_NO             -0.0982
# IsDepDelayed_YES             0.0982
# UniqueCarrier_AA            -0.0521
# UniqueCarrier_CO            -0.0279
# UniqueCarrier_DL            -0.0593
# UniqueCarrier_HP            -0.1183
# UniqueCarrier_PI            -0.0551
# UniqueCarrier_PS            -0.1137
# UniqueCarrier_TW            -0.0345
# UniqueCarrier_UA            -0.2115
# UniqueCarrier_US            -0.3482
# UniqueCarrier_WN             1.0000
