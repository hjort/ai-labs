# %% [markdown]
# https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236

# %%
import pandas as pd

# %%
data = pd.read_csv('data/otr-10k.csv')

# %%
data.head(10).T
# Out:
#                               0           1           2           3  \
# FL_DATE              2019-01-01  2019-01-01  2019-01-01  2019-01-01
# OP_CARRIER                   DL          DL          DL          DL
# OP_CARRIER_FL_NUM            40          41          68          69
# ORIGIN                      LAX         JFK         PDX         LAX
# DEST                        JFK         LAX         LAX         PDX
# CRS_DEP_TIME                920        1659        1106         730
# DEP_TIME                    915        1658        1100         733
# DEP_DELAY                    -5          -1          -6           3
# TAXI_OUT                     16          25           8          12
# TAXI_IN                       8           8          21           5
# CRS_ARR_TIME               1747        2030        1325        1003
# ARR_TIME                   1728        2024        1317        1006
# ARR_DELAY                   -19          -6          -8           3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109798 entries, 0 to 109797
# Data columns (total 26 columns):
# FL_DATE                109798 non-null object
# OP_CARRIER             109798 non-null object
# OP_CARRIER_FL_NUM      109798 non-null int64
# ORIGIN                 109798 non-null object
# DEST                   109798 non-null object
# CRS_DEP_TIME           109798 non-null int64
# DEP_TIME               107755 non-null float64
# DEP_DELAY              107755 non-null float64
# TAXI_OUT               107730 non-null float64
# TAXI_IN                107639 non-null float64
# CRS_ARR_TIME           109798 non-null int64
# ARR_TIME               107639 non-null float64
# ARR_DELAY              107419 non-null float64
# CANCELLED              109798 non-null float64
# CANCELLATION_CODE      2082 non-null object
# DIVERTED               109798 non-null float64
# CRS_ELAPSED_TIME       109798 non-null float64
# ACTUAL_ELAPSED_TIME    107419 non-null float64
# ...

# %%
data.describe(include='O').T
# Out:
#                     count unique         top   freq
# FL_DATE            109798     31  2019-01-02   3931
# OP_CARRIER         109798     12          WN  31944
# ORIGIN             109798    105         LAX  17988
# DEST               109798    103         LAX  17977
# CANCELLATION_CODE    2082      3           B   1120

# %%
data.describe().T
# Out:
#                         count         mean          std   min     25%     50%  \
# OP_CARRIER_FL_NUM    109798.0  2109.800297  1748.647443   1.0   736.0  1614.0
# CRS_DEP_TIME         109798.0  1324.235560   487.048870   3.0   905.0  1308.0
# DEP_TIME             107755.0  1328.639581   498.482927   1.0   908.0  1316.0
# DEP_DELAY            107755.0     9.473537    45.292556 -27.0    -6.0    -2.0
# TAXI_OUT             107730.0    17.873304     9.991857   1.0    12.0    15.0
# TAXI_IN              107639.0     7.471521     6.236377   1.0     4.0     6.0
# CRS_ARR_TIME         109798.0  1513.518206   510.614766   1.0  1126.0  1534.0
# ARR_TIME             107639.0  1495.327298   529.112188   1.0  1115.0  1527.0
# ARR_DELAY            107419.0     3.581163    48.102335 -85.0   -16.0    -7.0
# CANCELLED            109798.0     0.018962     0.136392   0.0     0.0     0.0
# DIVERTED             109798.0     0.002705     0.051939   0.0     0.0     0.0
# ...

# %%
data[data.DEP_DELAY >= 1200].head()
# Out:
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 3766   2019-01-02         NK                656    LAX  PIT          1450
# 6189   2019-01-02         NK                404    ATL  LAX          1120
# 15391  2019-01-05         AA               2363    FAT  DFW          1157
# 16427  2019-01-05         OO               5634    RNO  LAX          1920
# 21034  2019-01-06         OO               3058    LAX  MFR           933
#
#        DEP_TIME  DEP_DELAY  TAXI_OUT  TAXI_IN     ...       CRS_ELAPSED_TIME  \
# 3766     1406.0     1396.0      14.0      7.0     ...                  271.0
# 6189     1114.0     1434.0      33.0     11.0     ...                  306.0
# 15391    1528.0     1651.0      16.0     14.0     ...                  187.0
# 16427    1853.0     1413.0      64.0     13.0     ...                  110.0
# 21034     909.0     1416.0      40.0      3.0     ...                  129.0
#
# ...

# %%
data2 = pd.read_csv('data/681857647_T_ONTIME_REPORTING.csv')

# %%
# %time data2.drop([data2.columns.values[-1]], axis=1).to_csv('data/otr-ca-01.csv', index=False)
# Out:
# CPU times: user 18.7 s, sys: 408 ms, total: 19.1 s
# Wall time: 19.4 s

# %%
del(data2)
