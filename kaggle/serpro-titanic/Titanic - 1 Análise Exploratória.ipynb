# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('titanic-train.csv', index_col='person')

# mostrar alguns exemplos de registros
data.head()
# Out:
#         pclass survived                           name     sex   age  sibsp  \
# person
# 416          2       no            Gaskell, Mr. Alfred    male  16.0      0
# 194          1       no       Maguire, Mr. John Edward    male  30.0      0
# 600          3       no            Abbing, Mr. Anthony    male  42.0      0
# 1112         3       no      Peacock, Miss. Treasteall  female   3.0      1
# 878          3       no  Ilmakangas, Miss. Pieta Sofia  female  25.0      1
#
#         parch              ticket    fare cabin embarked  \
# person
# 416         0              239865  26.000   NaN        S
# 194         0              110469  26.000  C106        S
# 600         0           C.A. 5547   7.550   NaN        S
# 1112        1  SOTON/O.Q. 3101315  13.775   NaN        S
# 878         0    STON/O2. 3101271   7.925   NaN        S
#
#                 home_destination
# person
# 416     Liverpool / Montreal, PQ
# 194                 Brockton, MA
# 600                          NaN
# 1112                         NaN
# 878                          NaN

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (872, 12)

# %% [markdown]
# ## Análise dos dados

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872 entries, 416 to 1125
# Data columns (total 12 columns):
# pclass              872 non-null int64
# survived            872 non-null object
# name                872 non-null object
# sex                 872 non-null object
# age                 704 non-null float64
# sibsp               872 non-null int64
# parch               872 non-null int64
# ticket              872 non-null object
# fare                872 non-null float64
# cabin               208 non-null object
# embarked            870 non-null object
# home_destination    494 non-null object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 64.7+ KB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# age                 168
# cabin               664
# embarked              2
# home_destination    378
# dtype: int64

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#         count     mean      std   min      25%      50%      75%       max
# pclass  872.0   2.2810   0.8438  1.00   1.0000   3.0000   3.0000    3.0000
# age     704.0  29.4871  14.3915  0.17  21.0000  28.0000  38.0000   80.0000
# sibsp   872.0   0.4908   1.0131  0.00   0.0000   0.0000   1.0000    8.0000
# parch   872.0   0.3773   0.8347  0.00   0.0000   0.0000   0.0000    9.0000
# fare    872.0  31.9279  46.2903  0.00   7.8958  14.4542  30.7719  512.3292

# %%
# sumário das características textuais
data.describe(include=['O']).T
# Out:
#                  count unique                                     top freq
# survived           872      2                                      no  550
# name               872    872  Daly, Miss. Margaret Marcella "Maggie"    1
# sex                872      2                                    male  564
# ticket             872    674                                    1601    7
# cabin              208    154                                      G6    5
# embarked           870      3                                       S  617
# home_destination   494    289                            New York, NY   41

# %%
# quais as correlações entre as características numéricas?
data.corr()
# Out:
#         pclass     age   sibsp   parch    fare
# pclass  1.0000 -0.4396  0.0695  0.0156 -0.5721
# age    -0.4396  1.0000 -0.2487 -0.1694  0.1838
# sibsp   0.0695 -0.2487  1.0000  0.3849  0.1865
# parch   0.0156 -0.1694  0.3849  1.0000  0.2559
# fare   -0.5721  0.1838  0.1865  0.2559  1.0000

# %%
# show variable correlation which is more than 0.6 (positive or negative)
corr = data.corr()
corr[corr != 1][abs(corr) > 0.6].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.groupby('survived').mean()
# Out:
#           pclass      age   sibsp   parch     fare
# survived
# no        2.4709  30.0396  0.5109  0.3273  23.4128
# yes       1.9565  28.6148  0.4565  0.4627  46.4723

# %%
numeric_feats = data.dtypes[data.dtypes != "object"].index
numeric_feats
# Out:
# Index(['pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %% [raw]
# from scipy.stats import skew
# skewed_feats = data[numeric_feats].apply(lambda x: skew(x.dropna())) # compute skewness
# skewed_feats = skewed_feats[skewed_feats > 0.75]
# skewed_feats = skewed_feats.index
# skewed_feats

# %%
data.head(10).T
# Out:
# person                                416                       194   \
# pclass                                   2                         1
# survived                                no                        no
# name                   Gaskell, Mr. Alfred  Maguire, Mr. John Edward
# sex                                   male                      male
# age                                     16                        30
# sibsp                                    0                         0
# parch                                    0                         0
# ticket                              239865                    110469
# fare                                    26                        26
# cabin                                  NaN                      C106
# embarked                                 S                         S
# home_destination  Liverpool / Montreal, PQ              Brockton, MA
#
# person                           600                        1112  \
# pclass                              3                          3
# survived                           no                         no
# name              Abbing, Mr. Anthony  Peacock, Miss. Treasteall
# sex                              male                     female
# age                                42                          3
# sibsp                               0                          1
# parch                               0                          1
# ticket                      C.A. 5547         SOTON/O.Q. 3101315
# fare                             7.55                      13.78
# cabin                             NaN                        NaN
# embarked                            S                          S
# home_destination                  NaN                        NaN
#
# person                                     878                912   \
# pclass                                        3                  3
# survived                                     no                 no
# name              Ilmakangas, Miss. Pieta Sofia  Karaic, Mr. Milan
# sex                                      female               male
# age                                          25                 30
# sibsp                                         1                  0
# parch                                         0                  0
# ticket                         STON/O2. 3101271             349246
# fare                                      7.925              7.896
# cabin                                       NaN                NaN
# embarked                                      S                  S
# home_destination                            NaN                NaN
#
# person                             1305                             1061  \
# pclass                                3                                3
# survived                             no                              yes
# name              Zabour, Miss. Thamine  Nilsson, Miss. Helmina Josefina
# sex                              female                           female
# age                                 NaN                               26
# sibsp                                 1                                0
# parch                                 0                                0
# ticket                             2665                           347470
# fare                              14.45                            7.854
# cabin                               NaN                              NaN
# embarked                              C                                S
# home_destination                    NaN                              NaN
#
# person                        1019                                        1231
# pclass                           3                                           3
# survived                        no                                          no
# name              Mineff, Mr. Ivan  Strom, Mrs. Wilhelm (Elna Matilda Persson)
# sex                           male                                      female
# age                             24                                          29
# sibsp                            0                                           1
# parch                            0                                           1
# ticket                      349233                                      347054
# fare                         7.896                                       10.46
# cabin                          NaN                                          G6
# embarked                         S                                           S
# home_destination               NaN                                         NaN

# %% [raw]
# data[skewed_feats] = np.log1p(data[skewed_feats])

# %% [raw]
# data.head(10).T

# %% [raw]
# data = pd.get_dummies(data)
# data = data.fillna(data.mean())

# %%
data.isna().sum()
# Out:
# pclass                0
# survived              0
# name                  0
# sex                   0
# age                 168
# sibsp                 0
# parch                 0
# ticket                0
# fare                  0
# cabin               664
# embarked              2
# home_destination    378
# dtype: int64

# %%
data.sex.describe()
# Out:
# count      872
# unique       2
# top       male
# freq       564
# Name: sex, dtype: object

# %%
data.head()
# Out:
#         pclass survived                           name     sex   age  sibsp  \
# person
# 416          2       no            Gaskell, Mr. Alfred    male  16.0      0
# 194          1       no       Maguire, Mr. John Edward    male  30.0      0
# 600          3       no            Abbing, Mr. Anthony    male  42.0      0
# 1112         3       no      Peacock, Miss. Treasteall  female   3.0      1
# 878          3       no  Ilmakangas, Miss. Pieta Sofia  female  25.0      1
#
#         parch              ticket    fare cabin embarked  \
# person
# 416         0              239865  26.000   NaN        S
# 194         0              110469  26.000  C106        S
# 600         0           C.A. 5547   7.550   NaN        S
# 1112        1  SOTON/O.Q. 3101315  13.775   NaN        S
# 878         0    STON/O2. 3101271   7.925   NaN        S
#
#                 home_destination
# person
# 416     Liverpool / Montreal, PQ
# 194                 Brockton, MA
# 600                          NaN
# 1112                         NaN
# 878                          NaN

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# print(scaler.fit(data))
#
# data_scaled = pd.DataFrame(scaler.transform(data), columns=data.columns, index=data.index)
# data_scaled.head()
