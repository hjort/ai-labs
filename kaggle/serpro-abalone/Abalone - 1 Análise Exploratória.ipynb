# %% [markdown]
# ## Importação dos pacotes

# %%
# importar pacotes necessários
import numpy as np
import pandas as pd

# %%
# definir parâmetros extras
pd.set_option('precision', 4)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga dos dados

# %%
# carregar arquivo de dados de treino
data = pd.read_csv('abalone-train.csv', index_col='id')

# mostrar alguns exemplos de registros
data.head()
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# id
# 2758   M   0.535     0.430   0.155        0.7845          0.3285
# 1384   F   0.630     0.485   0.170        1.3205          0.5945
# 1131   M   0.565     0.435   0.150        0.9900          0.5795
# 3726   I   0.500     0.395   0.145        0.7865          0.3320
# 3445   I   0.495     0.400   0.145        0.5780          0.2545
#
#       viscera_weight  shell_weight  rings
# id
# 2758          0.1690        0.2450     10
# 1384          0.3450        0.3450      9
# 1131          0.1825        0.2060      8
# 3726          0.1815        0.2455      8
# 3445          0.1305        0.1645      8

# %%
# quantas linhas e colunas existem?
data.shape
# Out:
# (2784, 9)

# %% [markdown]
# ## Análise dos dados

# %%
# quais são as colunas e respectivos tipos de dados?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2784 entries, 2758 to 852
# Data columns (total 9 columns):
# sex               2784 non-null object
# length            2784 non-null float64
# diameter          2784 non-null float64
# height            2784 non-null float64
# whole_weight      2784 non-null float64
# shucked_weight    2784 non-null float64
# viscera_weight    2784 non-null float64
# shell_weight      2784 non-null float64
# rings             2784 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 206.6+ KB

# %%
# existem colunas com dados nulos?
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# sumário estatístico das características numéricas
data.describe().T
# Out:
#                  count    mean     std     min     25%      50%      75%  \
# length          2784.0  0.5218  0.1198  0.0750  0.4500   0.5400   0.6100
# diameter        2784.0  0.4059  0.0988  0.0550  0.3450   0.4200   0.4800
# height          2784.0  0.1387  0.0388  0.0000  0.1100   0.1400   0.1650
# whole_weight    2784.0  0.8168  0.4837  0.0020  0.4351   0.7853   1.1360
# shucked_weight  2784.0  0.3548  0.2186  0.0010  0.1819   0.3320   0.4981
# viscera_weight  2784.0  0.1781  0.1086  0.0005  0.0910   0.1675   0.2471
# shell_weight    2784.0  0.2347  0.1360  0.0015  0.1258   0.2300   0.3221
# rings           2784.0  9.9361  3.2405  1.0000  8.0000  10.0000  11.0000
#
#                     max
# length           0.8150
# diameter         0.6500
# height           0.5150
# whole_weight     2.7795
# shucked_weight   1.3485
# viscera_weight   0.7600
# shell_weight     0.8850
# rings           29.0000

# %%
# quais as correlações entre as características numéricas?
data.corr()
# Out:
#                 length  diameter  height  whole_weight  shucked_weight  \
# length           1.000     0.987   0.890         0.926           0.899
# diameter         0.987     1.000   0.896         0.926           0.895
# height           0.890     0.896   1.000         0.881           0.832
# whole_weight     0.926     0.926   0.881         1.000           0.970
# shucked_weight   0.899     0.895   0.832         0.970           1.000
# viscera_weight   0.902     0.900   0.858         0.970           0.935
# shell_weight     0.903     0.910   0.882         0.956           0.886
# rings            0.556     0.573   0.594         0.536           0.419
#
#                 viscera_weight  shell_weight  rings
# length                   0.902         0.903  0.556
# diameter                 0.900         0.910  0.573
# height                   0.858         0.882  0.594
# whole_weight             0.970         0.956  0.536
# shucked_weight           0.935         0.886  0.419
# viscera_weight           1.000         0.914  0.501
# shell_weight             0.914         1.000  0.623
# rings                    0.501         0.623  1.000

# %%
# show variable correlation which is more than 0.6 (positive or negative)
corr = data.corr()
corr[corr != 1][abs(corr) > 0.6].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
#                 length  diameter  height  whole_weight  shucked_weight  \
# length             NaN     0.987   0.890         0.926           0.899
# diameter         0.987       NaN   0.896         0.926           0.895
# height           0.890     0.896     NaN         0.881           0.832
# whole_weight     0.926     0.926   0.881           NaN           0.970
# shucked_weight   0.899     0.895   0.832         0.970             NaN
# viscera_weight   0.902     0.900   0.858         0.970           0.935
# shell_weight     0.903     0.910   0.882         0.956           0.886
# rings              NaN       NaN     NaN           NaN             NaN
#
#                 viscera_weight  shell_weight  rings
# length                   0.902         0.903    NaN
# diameter                 0.900         0.910    NaN
# height                   0.858         0.882    NaN
# whole_weight             0.970         0.956    NaN
# shucked_weight           0.935         0.886    NaN
# viscera_weight             NaN         0.914    NaN
# shell_weight             0.914           NaN  0.623
# rings                      NaN         0.623    NaN

# %%
data.groupby('rings').mean()
# Out:
#        length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# rings
# 1       0.075     0.055   0.010         0.002           0.001       5.000e-04
# 3       0.175     0.128   0.041         0.029           0.012       6.042e-03
# 4       0.223     0.165   0.054         0.060           0.025       1.296e-02
# 5       0.292     0.215   0.072         0.134           0.069       2.911e-02
# 6       0.365     0.275   0.090         0.265           0.119       5.719e-02
# 7       0.423     0.322   0.106         0.397           0.184       8.532e-02
# 8       0.497     0.384   0.127         0.638           0.292       1.377e-01
# 9       0.545     0.423   0.143         0.849           0.389       1.873e-01
# 10      0.569     0.444   0.153         0.978           0.431       2.161e-01
# 11      0.593     0.466   0.160         1.112           0.490       2.444e-01
# 12      0.591     0.463   0.161         1.102           0.475       2.437e-01
# 13      0.576     0.453   0.159         1.062           0.427       2.326e-01
# 14      0.576     0.456   0.164         1.072           0.428       2.318e-01
# 15      0.576     0.456   0.159         1.014           0.398       2.209e-01
# 16      0.588     0.470   0.169         1.114           0.423       2.407e-01
# 17      0.603     0.473   0.172         1.220           0.461       2.536e-01
# 18      0.585     0.461   0.172         1.131           0.418       2.330e-01
# 19      0.591     0.470   0.169         1.140           0.431       2.424e-01
# 20      0.605     0.481   0.173         1.250           0.453       2.581e-01
# 21      0.613     0.484   0.169         1.210           0.434       2.370e-01
# 22      0.569     0.443   0.176         0.926           0.308       1.726e-01
# 23      0.617     0.487   0.172         1.279           0.452       2.793e-01
# 24      0.700     0.540   0.215         1.978           0.667       3.125e-01
# 25      0.645     0.490   0.215         1.406           0.426       2.285e-01
# 26      0.600     0.495   0.195         1.058           0.384       1.900e-01
# 27      0.665     0.535   0.225         2.183           0.753       3.910e-01
# 29      0.700     0.585   0.185         1.808           0.706       3.215e-01
#
#        shell_weight
# rings
# 1             0.002
# 3             0.009
# 4             0.018
# 5             0.039
# 6             0.077
# 7             0.111
# 8             0.178
# 9             0.234
# 10            0.275
# 11            0.311
# 12            0.317
# 13            0.315
# 14            0.327
# 15            0.314
# 16            0.361
# 17            0.388
# 18            0.354
# 19            0.357
# 20            0.430
# 21            0.426
# 22            0.301
# 23            0.389
# 24            0.710
# 25            0.510
# 26            0.375
# 27            0.885
# 29            0.475

# %%
numeric_feats = data.dtypes[data.dtypes != "object"].index
numeric_feats
# Out:
# Index(['length', 'diameter', 'height', 'whole_weight', 'shucked_weight',
#        'viscera_weight', 'shell_weight', 'rings'],
#       dtype='object')

# %% [raw]
# from scipy.stats import skew
# skewed_feats = data[numeric_feats].apply(lambda x: skew(x.dropna())) # compute skewness
# skewed_feats = skewed_feats[skewed_feats > 0.75]
# skewed_feats = skewed_feats.index
# skewed_feats

# %%
data.head(10).T
# Out:
# id               2758   1384   1131   3726   3445    817    2742   3757  \
# sex                 M      F      M      I      I       I      I      I
# length          0.535   0.63  0.565    0.5  0.495    0.35   0.46   0.52
# diameter         0.43  0.485  0.435  0.395    0.4    0.27  0.345   0.41
# height          0.155   0.17   0.15  0.145  0.145    0.09  0.105   0.14
# whole_weight    0.784   1.32   0.99  0.786  0.578   0.205  0.415  0.699
# shucked_weight  0.329  0.595   0.58  0.332  0.255   0.075  0.187   0.34
# viscera_weight  0.169  0.345  0.182  0.181  0.131  0.0575  0.087  0.129
# shell_weight    0.245  0.345  0.206  0.245  0.165   0.062   0.11  0.195
# rings              10      9      8      8      8       6      8     10
#
# id               2609    2728
# sex                 F       I
# length           0.63   0.405
# diameter        0.495    0.31
# height            0.2    0.11
# whole_weight     1.43    0.91
# shucked_weight  0.659   0.416
# viscera_weight  0.336   0.207
# shell_weight     0.38  0.0995
# rings              11       8

# %% [raw]
# data[skewed_feats] = np.log1p(data[skewed_feats])

# %% [raw]
# data.head(10).T

# %% [raw]
# data = pd.get_dummies(data)
# data = data.fillna(data.mean())

# %%
data.isna().sum()
# Out:
# sex               0
# length            0
# diameter          0
# height            0
# whole_weight      0
# shucked_weight    0
# viscera_weight    0
# shell_weight      0
# rings             0
# dtype: int64

# %%
data.sex.describe()
# Out:
# count     2784
# unique       3
# top          M
# freq       992
# Name: sex, dtype: object

# %% [raw]
# print(data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))

# %%
data.head()
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# id
# 2758   M   0.535     0.430   0.155         0.784           0.329
# 1384   F   0.630     0.485   0.170         1.321           0.595
# 1131   M   0.565     0.435   0.150         0.990           0.580
# 3726   I   0.500     0.395   0.145         0.786           0.332
# 3445   I   0.495     0.400   0.145         0.578           0.255
#
#       viscera_weight  shell_weight  rings
# id
# 2758           0.169         0.245     10
# 1384           0.345         0.345      9
# 1131           0.182         0.206      8
# 3726           0.181         0.245      8
# 3445           0.131         0.165      8

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(data))

data_scaled = pd.DataFrame(scaler.transform(data), columns=data.columns, index=data.index)
data_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-055832896501> in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
# ----> 3 print(scaler.fit(data))
#       4
#       5 data_scaled = pd.DataFrame(scaler.transform(data), columns=data.columns, index=data.index)
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# --> 323         return self.partial_fit(X, y)
#     324
#     325     def partial_fit(self, X, y=None):
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     349         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     350                         estimator=self, dtype=FLOAT_DTYPES,
# --> 351                         force_all_finite="allow-nan")
#     352
#     353         data_min = np.nanmin(X, axis=0)
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: could not convert string to float: 'M'
